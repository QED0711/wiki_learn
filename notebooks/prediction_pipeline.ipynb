# %% [markdown]
# This notebook shows how to use a `GraphCreator` instance in a recommendation pipeline to easily produce the top recommendations and display their predicted order (before/after)

# %%
# %load_ext autoreload
# %autoreload 1

import sys
sys.path.append('../utils/')

import pickle
import numpy as np
import pandas as pd

from GraphAPI import GraphCreator
from RecommenderPipeline import Recommender

from sklearn.preprocessing import normalize, StandardScaler, Normalizer, RobustScaler, MinMaxScaler, MaxAbsScaler


# %aimport GraphAPI
# %aimport RecommenderPipeline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Load in Models

# %%
with open("../models/rf_classifier_v2_normalized.pkl", "rb") as model:
    rf_classifier = pickle.load(model)
    
with open("../models/xg_model_semisupervised_v2.pkl", "rb") as model:
    xg_classifier = pickle.load(model)

# %% [markdown]
# # Initialize `GraphCreator` Instance
#
# After initialization, pass as an argument to a new recommender instance

# %%
gc = GraphCreator("Prevention science")
print("Layer 1 nodes:", len(gc.graph.nodes))
rec = Recommender(gc)
# Out:
# Layer 1 nodes: 35

# %% [markdown]
# # Fit the Recommender

# %%
rec.fit(scaler=Normalizer)

# %% [markdown]
# # Make Predictions
# Pass in your model to make predictions on the data

# %%
rec.predict(rf_classifier)
# rec.predict(xg_classifier)

# %% [markdown]
# # Format the Results
# Will return as a dictionary containing the entry node and the predictions of the top articles.

# %%
rec.format_results()
# Out:
# {'entry': 'Prevention science',
#  'decision_threshold': 0.5500000000000003,
#  'predictions': [{'node': 'Protective factor',
#    'similarity_rank': 0.01737971568739465,
#    'label_proba': [0.40178310037624226, 0.5982168996237576],
#    'position': 'before'},
#   {'node': 'Medical sociology',
#    'similarity_rank': 0.012566392612513588,
#    'label_proba': [0.5191529984154043, 0.48084700158459553],
#    'position': 'before'},
#   {'node': 'Stroke',
#    'similarity_rank': 0.010844177475349555,
#    'label_proba': [0.5473228960438313, 0.4526771039561686],
#    'position': 'before'},
#   {'node': 'Emergency psychiatry',
#    'similarity_rank': 0.010580470435365714,
#    'label_proba': [0.5731768299574662, 0.426823170042534],
#    'position': 'after'},
#   {'node': 'Psychology',
#    'similarity_rank': 0.010254068319517255,
#    'label_proba': [0.4424448296578143, 0.5575551703421858],
#    'position': 'before'},
#   {'node': 'Social support',
#    'similarity_rank': 0.010193784411041597,
#    'label_proba': [0.5699847246943083, 0.43001527530569184],
#    'position': 'after'},
#   {'node': 'Community psychology',
#    'similarity_rank': 0.010030510505190729,
#    'label_proba': [0.555052178793688, 0.44494782120631216],
#    'position': 'after'},
#   {'node': 'Psychologist',
#    'similarity_rank': 0.010030510505190729,
#    'label_proba': [0.555052178793688, 0.44494782120631216],
#    'position': 'after'},
#   {'node': 'London',
#    'similarity_rank': 0.009810655074621921,
#    'label_proba': [0.5560080555822623, 0.44399194441773765],
#    'position': 'after'},
#   {'node': 'Drug court',
#    'similarity_rank': 0.009778752973623706,
#    'label_proba': [0.555052178793688, 0.44494782120631216],
#    'position': 'after'},
#   {'node': 'Policy',
#    'similarity_rank': 0.009647161872628667,
#    'label_proba': [0.46049370369979026, 0.5395062963002097],
#    'position': 'before'},
#   {'node': 'History of HIV/AIDS',
#    'similarity_rank': 0.009530683689224042,
#    'label_proba': [0.547121639872592, 0.4528783601274081],
#    'position': 'before'},
#   {'node': 'Social network',
#    'similarity_rank': 0.009421070621171743,
#    'label_proba': [0.549027875171878, 0.450972124828122],
#    'position': 'before'},
#   {'node': 'Suicidology',
#    'similarity_rank': 0.009291771208143312,
#    'label_proba': [0.5559204103521647, 0.44407958964783545],
#    'position': 'after'},
#   {'node': 'Doctor of Social Work',
#    'similarity_rank': 0.009230081985151123,
#    'label_proba': [0.4999570100355561, 0.5000429899644439],
#    'position': 'before'},
#   {'node': 'Suicide prevention',
#    'similarity_rank': 0.0092064555465358,
#    'label_proba': [0.5792715781996991, 0.42072842180030096],
#    'position': 'after'},
#   {'node': 'Education',
#    'similarity_rank': 0.009124765783312816,
#    'label_proba': [0.4336927108615778, 0.5663072891384223],
#    'position': 'before'},
#   {'node': 'HIV/AIDS in Taiwan',
#    'similarity_rank': 0.009085363625959308,
#    'label_proba': [0.5559204103521647, 0.44407958964783545],
#    'position': 'after'},
#   {'node': 'Society',
#    'similarity_rank': 0.008992884233616922,
#    'label_proba': [0.5560080555822623, 0.44399194441773765],
#    'position': 'after'},
#   {'node': 'Biological anthropology',
#    'similarity_rank': 0.00888280312428697,
#    'label_proba': [0.5873401935462181, 0.41265980645378214],
#    'position': 'after'},
#   {'node': 'Sociology',
#    'similarity_rank': 0.008868744211791875,
#    'label_proba': [0.4651737540705726, 0.5348262459294273],
#    'position': 'before'},
#   {'node': 'Health',
#    'similarity_rank': 0.008862964068646638,
#    'label_proba': [0.4651737540705726, 0.5348262459294273],
#    'position': 'before'},
#   {'node': 'Nutrition',
#    'similarity_rank': 0.008830995941200938,
#    'label_proba': [0.4981246621327944, 0.5018753378672056],
#    'position': 'before'},
#   {'node': 'Political science',
#    'similarity_rank': 0.00878251341685415,
#    'label_proba': [0.4466485952783842, 0.5533514047216159],
#    'position': 'before'},
#   {'node': 'Human nutrition',
#    'similarity_rank': 0.008656835993813516,
#    'label_proba': [0.5502990123361383, 0.44970098766386174],
#    'position': 'after'},
#   {'node': 'Anti-psychiatry',
#    'similarity_rank': 0.008655420876425032,
#    'label_proba': [0.5504424447225339, 0.44955755527746616],
#    'position': 'after'},
#   {'node': 'Behavioral neuroscience',
#    'similarity_rank': 0.008655420876425032,
#    'label_proba': [0.5504424447225339, 0.44955755527746616],
#    'position': 'after'},
#   {'node': 'List of counseling topics',
#    'similarity_rank': 0.008655420876425032,
#    'label_proba': [0.5504424447225339, 0.44955755527746616],
#    'position': 'after'},
#   {'node': 'Social science',
#    'similarity_rank': 0.008565524638274489,
#    'label_proba': [0.42320284698028765, 0.5767971530197125],
#    'position': 'before'},
#   {'node': 'Public health',
#    'similarity_rank': 0.008469075936631487,
#    'label_proba': [0.41623544713641686, 0.5837645528635832],
#    'position': 'before'},
#   {'node': 'Guillain–Barré syndrome',
#    'similarity_rank': 0.008447540653675562,
#    'label_proba': [0.5435674447225339, 0.456432555277466],
#    'position': 'before'},
#   {'node': 'Developmental psychology',
#    'similarity_rank': 0.008343373444476864,
#    'label_proba': [0.429927528675343, 0.5700724713246571],
#    'position': 'before'},
#   {'node': 'Social hygiene movement',
#    'similarity_rank': 0.008289949761640476,
#    'label_proba': [0.5333954821484899, 0.46660451785151025],
#    'position': 'before'},
#   {'node': 'Social psychology',
#    'similarity_rank': 0.008265498509699393,
#    'label_proba': [0.46645284838429796, 0.5335471516157021],
#    'position': 'before'},
#   {'node': 'Anthropology',
#    'similarity_rank': 0.008153723944913512,
#    'label_proba': [0.48432429391266973, 0.5156757060873303],
#    'position': 'before'},
#   {'node': 'Caesarean section',
#    'similarity_rank': 0.008113541246285954,
#    'label_proba': [0.5438109912819266, 0.4561890087180734],
#    'position': 'before'},
#   {'node': 'Geography',
#    'similarity_rank': 0.008035425248448027,
#    'label_proba': [0.48432429391266973, 0.5156757060873303],
#    'position': 'before'},
#   {'node': 'Traumatic brain injury',
#    'similarity_rank': 0.008011790923509765,
#    'label_proba': [0.5740365834884351, 0.425963416511565],
#    'position': 'after'},
#   {'node': "Women's health",
#    'similarity_rank': 0.007990797170531479,
#    'label_proba': [0.552411473562921, 0.44758852643707914],
#    'position': 'after'},
#   {'node': 'Anti-social behaviour',
#    'similarity_rank': 0.007959879854880525,
#    'label_proba': [0.47348192037271986, 0.52651807962728],
#    'position': 'before'},
#   {'node': 'International Statistical Classification of Diseases and Related Health Problems',
#    'similarity_rank': 0.007950991497536739,
#    'label_proba': [0.5021842136211527, 0.4978157863788473],
#    'position': 'before'},
#   {'node': 'Fetal alcohol spectrum disorder',
#    'similarity_rank': 0.007939779212375334,
#    'label_proba': [0.5772730882830602, 0.42272691171694],
#    'position': 'after'},
#   {'node': 'Economics',
#    'similarity_rank': 0.00791365272371818,
#    'label_proba': [0.41986042341218516, 0.5801395765878151],
#    'position': 'before'},
#   {'node': 'Mental disorder',
#    'similarity_rank': 0.007872674686811706,
#    'label_proba': [0.46836585933373054, 0.5316341406662695],
#    'position': 'before'},
#   {'node': 'Passive smoking',
#    'similarity_rank': 0.007755526482482685,
#    'label_proba': [0.5661580327271989, 0.4338419672728012],
#    'position': 'after'},
#   {'node': 'Cancer',
#    'similarity_rank': 0.007709411824610171,
#    'label_proba': [0.5228949040583275, 0.4771050959416725],
#    'position': 'before'},
#   {'node': 'Cognitive behavioral therapy',
#    'similarity_rank': 0.00769953733402663,
#    'label_proba': [0.43091554472433463, 0.5690844552756655],
#    'position': 'before'},
#   {'node': 'Western Washington University',
#    'similarity_rank': 0.00766256641612063,
#    'label_proba': [0.5744408899244082, 0.42555911007559194],
#    'position': 'after'},
#   {'node': 'Combined oral contraceptive pill',
#    'similarity_rank': 0.007617805181999363,
#    'label_proba': [0.5661580327271989, 0.4338419672728012],
#    'position': 'after'},
#   {'node': 'Sexual objectification',
#    'similarity_rank': 0.007555376692462197,
#    'label_proba': [0.5449884543169259, 0.4550115456830741],
#    'position': 'before'},
#   {'node': 'Specialty (medicine)',
#    'similarity_rank': 0.0074501238746746,
#    'label_proba': [0.53323015340407, 0.46676984659592996],
#    'position': 'before'},
#   {'node': 'Complication (medicine)',
#    'similarity_rank': 0.007383491070821148,
#    'label_proba': [0.5541978960438313, 0.44580210395616876],
#    'position': 'after'},
#   {'node': 'Adoption',
#    'similarity_rank': 0.007358970362406221,
#    'label_proba': [0.5627954103521647, 0.4372045896478354],
#    'position': 'after'},
#   {'node': 'Healthy diet',
#    'similarity_rank': 0.007353831457128758,
#    'label_proba': [0.5504408949936882, 0.4495591050063119],
#    'position': 'after'},
#   {'node': 'Intellectual disability',
#    'similarity_rank': 0.007331447797605908,
#    'label_proba': [0.5559204103521647, 0.44407958964783545],
#    'position': 'after'},
#   {'node': 'Philosophy of psychology',
#    'similarity_rank': 0.007307483846612792,
#    'label_proba': [0.44984070054154207, 0.550159299458458],
#    'position': 'before'},
#   {'node': 'Centers for Disease Control and Prevention',
#    'similarity_rank': 0.007261076808388135,
#    'label_proba': [0.483832325716304, 0.516167674283696],
#    'position': 'before'},
#   {'node': 'Psychotherapy',
#    'similarity_rank': 0.0072596900144249734,
#    'label_proba': [0.44984070054154207, 0.550159299458458],
#    'position': 'before'},
#   {'node': 'Rape',
#    'similarity_rank': 0.007187112186698466,
#    'label_proba': [0.5592155423824399, 0.4407844576175603],
#    'position': 'after'},
#   {'node': 'Molecular pathological epidemiology',
#    'similarity_rank': 0.007170166961628388,
#    'label_proba': [0.5918832804105204, 0.4081167195894798],
#    'position': 'after'},
#   {'node': 'Hispanic paradox',
#    'similarity_rank': 0.007170166961628388,
#    'label_proba': [0.5918832804105204, 0.4081167195894798],
#    'position': 'after'},
#   {'node': 'Randomized controlled trial',
#    'similarity_rank': 0.0071410127989131825,
#    'label_proba': [0.5529590577877195, 0.44704094221228063],
#    'position': 'after'},
#   {'node': 'Social rejection',
#    'similarity_rank': 0.007126285066150691,
#    'label_proba': [0.5654742599487786, 0.4345257400512213],
#    'position': 'after'},
#   {'node': 'Recovery approach',
#    'similarity_rank': 0.0071259482647758185,
#    'label_proba': [0.48897777658797287, 0.5110222234120271],
#    'position': 'before'},
#   {'node': 'Mental health professional',
#    'similarity_rank': 0.0071259482647758185,
#    'label_proba': [0.48897777658797287, 0.5110222234120271],
#    'position': 'before'},
#   {'node': 'Music therapy',
#    'similarity_rank': 0.007087113157985159,
#    'label_proba': [0.4757265952013108, 0.5242734047986892],
#    'position': 'before'},
#   {'node': 'Cognitive psychology',
#    'similarity_rank': 0.007087113157985159,
#    'label_proba': [0.4757265952013108, 0.5242734047986892],
#    'position': 'before'},
#   {'node': 'Abnormal psychology',
#    'similarity_rank': 0.007087113157985159,
#    'label_proba': [0.4757265952013108, 0.5242734047986892],
#    'position': 'before'},
#   {'node': 'Law',
#    'similarity_rank': 0.007087113157985159,
#    'label_proba': [0.4757265952013108, 0.5242734047986892],
#    'position': 'before'},
#   {'node': 'Personality psychology',
#    'similarity_rank': 0.007087113157985159,
#    'label_proba': [0.4757265952013108, 0.5242734047986892],
#    'position': 'before'},
#   {'node': 'Harm reduction',
#    'similarity_rank': 0.007079145082245555,
#    'label_proba': [0.5592155423824399, 0.4407844576175603],
#    'position': 'after'},
#   {'node': 'World Health Organization',
#    'similarity_rank': 0.007062383711755103,
#    'label_proba': [0.4754168933824471, 0.524583106617553],
#    'position': 'before'},
#   {'node': 'History of mental disorders',
#    'similarity_rank': 0.006997463670871693,
#    'label_proba': [0.5623405423824398, 0.4376594576175603],
#    'position': 'after'},
#   {'node': 'Deinstitutionalisation',
#    'similarity_rank': 0.006997463670871693,
#    'label_proba': [0.5623405423824398, 0.4376594576175603],
#    'position': 'after'},
#   {'node': 'Applied psychology',
#    'similarity_rank': 0.006997463670871693,
#    'label_proba': [0.5623405423824398, 0.4376594576175603],
#    'position': 'after'},
#   {'node': 'JSTOR',
#    'similarity_rank': 0.006986785217218675,
#    'label_proba': [0.499780885354974, 0.500219114645026],
#    'position': 'before'},
#   {'node': 'Prison',
#    'similarity_rank': 0.006898542061579129,
#    'label_proba': [0.5622821546856208, 0.4377178453143792],
#    'position': 'after'},
#   {'node': 'Occupational safety and health',
#    'similarity_rank': 0.0068684186163108394,
#    'label_proba': [0.49486128491570214, 0.5051387150842978],
#    'position': 'before'},
#   {'node': 'Health psychology',
#    'similarity_rank': 0.0068684186163108394,
#    'label_proba': [0.49486128491570214, 0.5051387150842978],
#    'position': 'before'},
#   {'node': 'History',
#    'similarity_rank': 0.006867178717945916,
#    'label_proba': [0.4466485952783842, 0.5533514047216159],
#    'position': 'before'},
#   {'node': 'Community health',
#    'similarity_rank': 0.006852654017133957,
#    'label_proba': [0.561803918679894, 0.438196081320106],
#    'position': 'after'},
#   {'node': 'Health equity',
#    'similarity_rank': 0.006852654017133957,
#    'label_proba': [0.561803918679894, 0.438196081320106],
#    'position': 'after'},
#   {'node': 'Vulva',
#    'similarity_rank': 0.006840402464051649,
#    'label_proba': [0.5850082804105203, 0.4149917195894798],
#    'position': 'after'},
#   {'node': 'Non-communicable disease',
#    'similarity_rank': 0.0068377156195638346,
#    'label_proba': [0.5749134579756079, 0.4250865420243922],
#    'position': 'after'},
#   {'node': 'Family therapy',
#    'similarity_rank': 0.006835470087540021,
#    'label_proba': [0.4688515952013107, 0.5311484047986892],
#    'position': 'before'},
#   {'node': 'Risk ratio',
#    'similarity_rank': 0.006830238442458119,
#    'label_proba': [0.5697640873070507, 0.4302359126929493],
#    'position': 'after'},
#   {'node': 'Psychiatric history',
#    'similarity_rank': 0.0068267098364281995,
#    'label_proba': [0.5622821546856208, 0.4377178453143792],
#    'position': 'after'},
#   {'node': 'Sociology of health and illness',
#    'similarity_rank': 0.006773300239889094,
#    'label_proba': [0.5502990123361383, 0.44970098766386174],
#    'position': 'after'},
#   {'node': 'Preventive healthcare',
#    'similarity_rank': 0.006773300239889094,
#    'label_proba': [0.5502990123361383, 0.44970098766386174],
#    'position': 'after'},
#   {'node': 'Health communication',
#    'similarity_rank': 0.006773300239889094,
#    'label_proba': [0.5502990123361383, 0.44970098766386174],
#    'position': 'after'},
#   {'node': "Alzheimer's disease",
#    'similarity_rank': 0.0067498084259921196,
#    'label_proba': [0.5232130987210806, 0.47678690127891943],
#    'position': 'before'},
#   {'node': 'Substance abuse prevention',
#    'similarity_rank': 0.006745660608752013,
#    'label_proba': [0.5623405423824398, 0.4376594576175603],
#    'position': 'after'},
#   {'node': 'Analysis of variance',
#    'similarity_rank': 0.006741379204414387,
#    'label_proba': [0.5472871176887297, 0.45271288231127044],
#    'position': 'before'},
#   {'node': 'Social stigma',
#    'similarity_rank': 0.006726525164557711,
#    'label_proba': [0.5078897316464477, 0.49211026835355226],
#    'position': 'before'},
#   {'node': 'Dialectical behavior therapy',
#    'similarity_rank': 0.006724564728807217,
#    'label_proba': [0.4873828731111763, 0.5126171268888237],
#    'position': 'before'},
#   {'node': 'Index of psychology articles',
#    'similarity_rank': 0.006704324632131002,
#    'label_proba': [0.5850082804105203, 0.4149917195894798],
#    'position': 'after'},
#   {'node': 'Public health intervention',
#    'similarity_rank': 0.006666751107020229,
#    'label_proba': [0.5531486958857075, 0.4468513041142924],
#    'position': 'after'},
#   {'node': 'Birth control',
#    'similarity_rank': 0.00664349752808843,
#    'label_proba': [0.5652020272085585, 0.43479797279144156],
#    'position': 'after'},
#   {'node': 'Science and technology studies',
#    'similarity_rank': 0.006619195089295751,
#    'label_proba': [0.5591484371192819, 0.44085156288071814],
#    'position': 'after'}]}

# %% [markdown]
# # Optional: Format as DataFrame for Easy Viewing

# %%
recommendations = pd.DataFrame(rec.format_results()['predictions'])
print(recommendations.position.value_counts())
recommendations
# Out:
# before    50
# after     49
# Name: position, dtype: int64
#                               node  similarity_rank  \
# 0                Protective factor         0.017380
# 1                Medical sociology         0.012566
# 2                           Stroke         0.010844
# 3             Emergency psychiatry         0.010580
# 4                       Psychology         0.010254
# ..                             ...              ...
# 94    Dialectical behavior therapy         0.006725
# 95    Index of psychology articles         0.006704
# 96      Public health intervention         0.006667
# 97                   Birth control         0.006643
# 98  Science and technology studies         0.006619
#
#                                   label_proba position
# 0   [0.40178310037624226, 0.5982168996237576]   before
# 1   [0.5191529984154043, 0.48084700158459553]   before
# 2    [0.5473228960438313, 0.4526771039561686]   before
# 3     [0.5731768299574662, 0.426823170042534]    after
# 4    [0.4424448296578143, 0.5575551703421858]   before
# ..                                        ...      ...
# 94   [0.4873828731111763, 0.5126171268888237]   before
# 95   [0.5850082804105203, 0.4149917195894798]    after
# 96   [0.5531486958857075, 0.4468513041142924]    after
# 97  [0.5652020272085585, 0.43479797279144156]    after
# 98  [0.5591484371192819, 0.44085156288071814]    after
#
# [99 rows x 4 columns]
