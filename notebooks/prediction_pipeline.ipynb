# %% [markdown]
# This notebook shows how to use a `GraphCreator` instance in a recommendation pipeline to easily produce the top recommendations and display their predicted order (before/after)

# %%
# %load_ext autoreload
# %autoreload 1

import sys
sys.path.append('../utils/')

import pickle
import numpy as np
import pandas as pd

from GraphAPI import GraphCreator
from RecommenderPipeline import Recommender

from sklearn.preprocessing import normalize, StandardScaler, Normalizer, RobustScaler, MinMaxScaler, MaxAbsScaler


# %aimport GraphAPI
# %aimport RecommenderPipeline

# %% [markdown]
# # Load in Models

# %%
with open("../models/rf_classifier_v2.pkl", "rb") as model:
    rf_classifier = pickle.load(model)
    
with open("../models/xg_model_semisupervised_v2.pkl", "rb") as model:
    xg_classifier = pickle.load(model)

# %% [markdown]
# # Initialize `GraphCreator` Instance
#
# After initialization, pass as an argument to a new recommender instance

# %%
gc = GraphCreator("https://en.wikipedia.org/wiki/Receiver_operating_characteristic")

rec = Recommender(gc)

# %% [markdown]
# # Fit the Recommender

# %%
rec.fit(scaler=Normalizer)

# %% [markdown]
# # Make Predictions
# Pass in your model to make predictions on the data

# %%
rec.predict(rf_classifier)
# rec.predict(xg_classifier)

# %% [markdown]
# # Format the Results
# Will return as a dictionary containing the entry node and the predictions of the top articles.

# %%
rec.format_results()
# Out:
# {'entry': 'Receiver operating characteristic',
#  'predictions': [{'node': 'Detection error tradeoff',
#    'similarity_rank': 0.06624103913601846,
#    'label_proba': [0.48295221130911925, 0.5170477886908806],
#    'position': 'before'},
#   {'node': 'Diagnostic odds ratio',
#    'similarity_rank': 0.04565181757444286,
#    'label_proba': [0.5357898564711393, 0.4642101435288606],
#    'position': 'after'},
#   {'node': 'Net reclassification improvement',
#    'similarity_rank': 0.0413328706690984,
#    'label_proba': [0.6657316763483345, 0.3342683236516654],
#    'position': 'after'},
#   {'node': 'Constant false alarm rate',
#    'similarity_rank': 0.040766376010195414,
#    'label_proba': [0.5435104298877957, 0.4564895701122042],
#    'position': 'after'},
#   {'node': 'Sensitivity index',
#    'similarity_rank': 0.04071341295719475,
#    'label_proba': [0.5361368750439643, 0.4638631249560356],
#    'position': 'after'},
#   {'node': 'Brier score',
#    'similarity_rank': 0.040391635888027994,
#    'label_proba': [0.4003525916218635, 0.5996474083781366],
#    'position': 'before'},
#   {'node': 'Lift (data mining)',
#    'similarity_rank': 0.03799749966463004,
#    'label_proba': [0.5392185207901286, 0.4607814792098715],
#    'position': 'after'},
#   {'node': "Youden's J statistic",
#    'similarity_rank': 0.03716216083738312,
#    'label_proba': [0.5323907790859558, 0.4676092209140441],
#    'position': 'after'},
#   {'node': 'Positive and negative predictive values',
#    'similarity_rank': 0.024235217495834262,
#    'label_proba': [0.5715732993875478, 0.42842670061245214],
#    'position': 'after'},
#   {'node': 'F1 score',
#    'similarity_rank': 0.02233029812652481,
#    'label_proba': [0.5248004778131767, 0.47519952218682326],
#    'position': 'after'},
#   {'node': 'Matthews correlation coefficient',
#    'similarity_rank': 0.018237875514634797,
#    'label_proba': [0.5433385372337669, 0.45666146276623293],
#    'position': 'after'},
#   {'node': "Fleiss' kappa",
#    'similarity_rank': 0.01754615015719349,
#    'label_proba': [0.5418618960587068, 0.4581381039412931],
#    'position': 'after'},
#   {'node': 'False positive rate',
#    'similarity_rank': 0.012919502679593025,
#    'label_proba': [0.40102777813951507, 0.598972221860485],
#    'position': 'before'},
#   {'node': 'Confusion matrix',
#    'similarity_rank': 0.010738440466184036,
#    'label_proba': [0.5460122867244627, 0.4539877132755372],
#    'position': 'after'},
#   {'node': 'False positives and false negatives',
#    'similarity_rank': 0.00828753652347231,
#    'label_proba': [0.49806524793137924, 0.5019347520686207],
#    'position': 'before'},
#   {'node': 'Precision and recall',
#    'similarity_rank': 0.007740383388474155,
#    'label_proba': [0.42456513267930485, 0.5754348673206953],
#    'position': 'before'},
#   {'node': 'False alarm',
#    'similarity_rank': 0.0051188399518306065,
#    'label_proba': [0.4230481849036158, 0.5769518150963844],
#    'position': 'before'},
#   {'node': 'OpenEpi',
#    'similarity_rank': 0.0029401068984368757,
#    'label_proba': [0.6595537483665156, 0.3404462516334842],
#    'position': 'after'},
#   {'node': 'Likelihood ratios in diagnostic testing',
#    'similarity_rank': 0.0027072664063712624,
#    'label_proba': [0.4909685091005892, 0.5090314908994108],
#    'position': 'before'},
#   {'node': 'Natural hazard',
#    'similarity_rank': 0.0026937876324817866,
#    'label_proba': [0.5667546190159252, 0.4332453809840749],
#    'position': 'after'},
#   {'node': 'Detection theory',
#    'similarity_rank': 0.0024865884745069026,
#    'label_proba': [0.6519897246747042, 0.3480102753252957],
#    'position': 'after'},
#   {'node': 'Sensitivity and specificity',
#    'similarity_rank': 0.002315653118820285,
#    'label_proba': [0.5145986996860163, 0.48540130031398365],
#    'position': 'after'},
#   {'node': 'Binary classification',
#    'similarity_rank': 0.0022218562913775097,
#    'label_proba': [0.643564276078627, 0.3564357239213728],
#    'position': 'after'},
#   {'node': 'Injury prevention',
#    'similarity_rank': 0.0018265062972493771,
#    'label_proba': [0.4923708562311362, 0.5076291437688637],
#    'position': 'before'},
#   {'node': 'Risk ratio',
#    'similarity_rank': 0.001764355831142998,
#    'label_proba': [0.5611522488431704, 0.4388477511568295],
#    'position': 'after'},
#   {'node': 'False discovery rate',
#    'similarity_rank': 0.0017078665112128949,
#    'label_proba': [0.6476662117774811, 0.3523337882225188],
#    'position': 'after'},
#   {'node': 'Total operating characteristic',
#    'similarity_rank': 0.0011793836109367441,
#    'label_proba': [0.4623974502960808, 0.5376025497039192],
#    'position': 'before'},
#   {'node': 'Forecasting',
#    'similarity_rank': 0.0011383451249434744,
#    'label_proba': [0.4567594006294891, 0.5432405993705108],
#    'position': 'before'},
#   {'node': 'Receiver Operating Characteristic Curve Explorer and Tester',
#    'similarity_rank': 0.0010157031415151698,
#    'label_proba': [0.4863609942993602, 0.5136390057006398],
#    'position': 'before'},
#   {'node': 'Biometrics',
#    'similarity_rank': 0.0010001411922879021,
#    'label_proba': [0.4474366788939513, 0.5525633211060488],
#    'position': 'before'},
#   {'node': 'Coefficient of determination',
#    'similarity_rank': 0.0009793220054865595,
#    'label_proba': [0.47904490393715543, 0.5209550960628446],
#    'position': 'before'},
#   {'node': 'Multivariate adaptive regression spline',
#    'similarity_rank': 0.000871142998228336,
#    'label_proba': [0.5021312312650119, 0.4978687687349879],
#    'position': 'after'},
#   {'node': 'Cumulative distribution function',
#    'similarity_rank': 0.0008616105312737795,
#    'label_proba': [0.5026221948696694, 0.49737780513033053],
#    'position': 'after'},
#   {'node': 'Distance correlation',
#    'similarity_rank': 0.0008133932456808969,
#    'label_proba': [0.4460076192321419, 0.5539923807678582],
#    'position': 'before'},
#   {'node': 'William Sealy Gosset',
#    'similarity_rank': 0.0008120393377838722,
#    'label_proba': [0.47470203633884567, 0.5252979636611542],
#    'position': 'before'},
#   {'node': 'Microsoft Excel',
#    'similarity_rank': 0.0008109579523657433,
#    'label_proba': [0.43441478967376546, 0.5655852103262347],
#    'position': 'before'},
#   {'node': 'Quality (business)',
#    'similarity_rank': 0.0008084086013472034,
#    'label_proba': [0.4460076192321419, 0.5539923807678582],
#    'position': 'before'},
#   {'node': 'Panel analysis',
#    'similarity_rank': 0.0008068187275360576,
#    'label_proba': [0.4491978296228675, 0.5508021703771325],
#    'position': 'before'},
#   {'node': 'Explained sum of squares',
#    'similarity_rank': 0.0008048205821897285,
#    'label_proba': [0.41982850515167996, 0.5801714948483202],
#    'position': 'before'},
#   {'node': "McNemar's test",
#    'similarity_rank': 0.0008011970501469038,
#    'label_proba': [0.45620224440182233, 0.5437977555981777],
#    'position': 'before'},
#   {'node': 'Contrast (statistics)',
#    'similarity_rank': 0.0008008270709806772,
#    'label_proba': [0.4313057083479192, 0.5686942916520811],
#    'position': 'before'},
#   {'node': 'Landscape architecture',
#    'similarity_rank': 0.0007972706737817704,
#    'label_proba': [0.5400799955918871, 0.45992000440811304],
#    'position': 'after'},
#   {'node': 'Total sum of squares',
#    'similarity_rank': 0.0007954959025454825,
#    'label_proba': [0.45182174717546736, 0.5481782528245325],
#    'position': 'before'},
#   {'node': 'Signal-to-noise ratio',
#    'similarity_rank': 0.0007953962913794167,
#    'label_proba': [0.4727047666402776, 0.5272952333597223],
#    'position': 'before'},
#   {'node': 'Drug',
#    'similarity_rank': 0.000795191382312206,
#    'label_proba': [0.44071152461649016, 0.5592884753835098],
#    'position': 'before'},
#   {'node': 'National Health and Nutrition Examination Survey',
#    'similarity_rank': 0.0007946310913394744,
#    'label_proba': [0.42847350998926714, 0.571526490010733],
#    'position': 'before'},
#   {'node': 'Noise',
#    'similarity_rank': 0.0007930986998545423,
#    'label_proba': [0.5207294928843915, 0.4792705071156086],
#    'position': 'after'},
#   {'node': 'Signal processing',
#    'similarity_rank': 0.0007917114649713658,
#    'label_proba': [0.42889252893723956, 0.5711074710627606],
#    'position': 'before'},
#   {'node': 'Scurvy',
#    'similarity_rank': 0.0007915259277647535,
#    'label_proba': [0.381926089009824, 0.6180739109901761],
#    'position': 'before'},
#   {'node': 'Bhattacharyya distance',
#    'similarity_rank': 0.000789469384419756,
#    'label_proba': [0.478358873288003, 0.5216411267119969],
#    'position': 'before'},
#   {'node': 'Data dredging',
#    'similarity_rank': 0.0007891762662550764,
#    'label_proba': [0.46614938361750335, 0.5338506163824966],
#    'position': 'before'},
#   {'node': 'Kernel density estimation',
#    'similarity_rank': 0.0007884594084758222,
#    'label_proba': [0.4744182737554935, 0.5255817262445064],
#    'position': 'before'},
#   {'node': 'Research',
#    'similarity_rank': 0.0007880476744374078,
#    'label_proba': [0.38535770809742265, 0.6146422919025772],
#    'position': 'before'},
#   {'node': 'Mining',
#    'similarity_rank': 0.0007858164649572428,
#    'label_proba': [0.4663387571621923, 0.5336612428378076],
#    'position': 'before'},
#   {'node': 'Wald–Wolfowitz runs test',
#    'similarity_rank': 0.0007849676375572072,
#    'label_proba': [0.4638748609051926, 0.5361251390948073],
#    'position': 'before'},
#   {'node': 'Open access',
#    'similarity_rank': 0.0007844017941061325,
#    'label_proba': [0.41208662453726785, 0.5879133754627321],
#    'position': 'before'},
#   {'node': "Cohen's kappa",
#    'similarity_rank': 0.00078378537712266,
#    'label_proba': [0.4465135771228324, 0.5534864228771676],
#    'position': 'before'},
#   {'node': 'Netherlands',
#    'similarity_rank': 0.0007837077215930326,
#    'label_proba': [0.42676249862215215, 0.5732375013778478],
#    'position': 'before'},
#   {'node': 'Human',
#    'similarity_rank': 0.0007813698593491787,
#    'label_proba': [0.478292673626398, 0.521707326373602],
#    'position': 'before'},
#   {'node': 'Stuart Pocock',
#    'similarity_rank': 0.0007807500034502466,
#    'label_proba': [0.46241794711021195, 0.5375820528897879],
#    'position': 'before'},
#   {'node': 'Glucose',
#    'similarity_rank': 0.0007805704095338971,
#    'label_proba': [0.4727047666402776, 0.5272952333597223],
#    'position': 'before'},
#   {'node': 'Indicator function',
#    'similarity_rank': 0.000779943906751438,
#    'label_proba': [0.4734325992625121, 0.5265674007374879],
#    'position': 'before'},
#   {'node': 'Software',
#    'similarity_rank': 0.0007793291360976977,
#    'label_proba': [0.47589497703100325, 0.5241050229689967],
#    'position': 'before'},
#   {'node': 'Aesthetics',
#    'similarity_rank': 0.0007788701087409507,
#    'label_proba': [0.4854695324205248, 0.5145304675794751],
#    'position': 'before'},
#   {'node': 'Sports injury',
#    'similarity_rank': 0.0007783629959017907,
#    'label_proba': [0.38592597432310427, 0.6140740256768957],
#    'position': 'before'},
#   {'node': 'Brucellosis',
#    'similarity_rank': 0.0007782807396188835,
#    'label_proba': [0.38592597432310427, 0.6140740256768957],
#    'position': 'before'},
#   {'node': 'Philippines',
#    'similarity_rank': 0.0007779452573389948,
#    'label_proba': [0.4614608578077033, 0.5385391421922967],
#    'position': 'before'},
#   {'node': 'Singapore',
#    'similarity_rank': 0.00077776533075068,
#    'label_proba': [0.462985641540251, 0.5370143584597489],
#    'position': 'before'},
#   {'node': 'Quantum mechanics',
#    'similarity_rank': 0.0007775259987047058,
#    'label_proba': [0.4663387571621923, 0.5336612428378076],
#    'position': 'before'},
#   {'node': 'Energy',
#    'similarity_rank': 0.0007773488969659435,
#    'label_proba': [0.46614938361750335, 0.5338506163824966],
#    'position': 'before'},
#   {'node': 'Leprosy',
#    'similarity_rank': 0.0007773429510865671,
#    'label_proba': [0.43403587777733305, 0.5659641222226669],
#    'position': 'before'},
#   {'node': 'Iris flower data set',
#    'similarity_rank': 0.000776732315879307,
#    'label_proba': [0.49448598263697496, 0.5055140173630249],
#    'position': 'before'},
#   {'node': 'Approximation',
#    'similarity_rank': 0.0007760211120073585,
#    'label_proba': [0.5486419035605985, 0.45135809643940156],
#    'position': 'after'},
#   {'node': 'Pakistan',
#    'similarity_rank': 0.0007759806992979027,
#    'label_proba': [0.4215074561718628, 0.5784925438281373],
#    'position': 'before'},
#   {'node': 'Taiwan',
#    'similarity_rank': 0.0007755235179593105,
#    'label_proba': [0.4325728681121891, 0.5674271318878108],
#    'position': 'before'},
#   {'node': 'Sub-Saharan Africa',
#    'similarity_rank': 0.0007753158359137896,
#    'label_proba': [0.45947373677834624, 0.5405262632216538],
#    'position': 'before'},
#   {'node': 'Type 2 diabetes',
#    'similarity_rank': 0.0007746978335471911,
#    'label_proba': [0.469760475834957, 0.5302395241650429],
#    'position': 'before'},
#   {'node': 'Limited dependent variable',
#    'similarity_rank': 0.0007746205006493453,
#    'label_proba': [0.49178727158139957, 0.5082127284186004],
#    'position': 'before'},
#   {'node': 'Allergy',
#    'similarity_rank': 0.0007739333320455289,
#    'label_proba': [0.3938437286588811, 0.6061562713411189],
#    'position': 'before'},
#   {'node': 'Electrical engineering',
#    'similarity_rank': 0.0007739236147264274,
#    'label_proba': [0.4455217235851461, 0.5544782764148538],
#    'position': 'before'},
#   {'node': 'Compulsory sterilization',
#    'similarity_rank': 0.0007737351864651902,
#    'label_proba': [0.41933396689311037, 0.5806660331068898],
#    'position': 'before'},
#   {'node': 'Creutzfeldt–Jakob disease',
#    'similarity_rank': 0.0007736884073485399,
#    'label_proba': [0.4842138038246418, 0.5157861961753581],
#    'position': 'before'},
#   {'node': 'Zika virus',
#    'similarity_rank': 0.0007734025419464827,
#    'label_proba': [0.4439017350072158, 0.5560982649927843],
#    'position': 'before'},
#   {'node': 'Human body',
#    'similarity_rank': 0.000773087382666134,
#    'label_proba': [0.4830056361635251, 0.5169943638364749],
#    'position': 'before'},
#   {'node': 'EHealth',
#    'similarity_rank': 0.0007730264659160387,
#    'label_proba': [0.4430578273281464, 0.5569421726718535],
#    'position': 'before'},
#   {'node': 'Infant',
#    'similarity_rank': 0.0007730190132941615,
#    'label_proba': [0.43403587777733305, 0.5659641222226669],
#    'position': 'before'},
#   {'node': 'Interdisciplinarity',
#    'similarity_rank': 0.000773018625854378,
#    'label_proba': [0.4638748609051926, 0.5361251390948073],
#    'position': 'before'},
#   {'node': 'Insomnia',
#    'similarity_rank': 0.0007729386234683777,
#    'label_proba': [0.48337887516455785, 0.5166211248354421],
#    'position': 'before'},
#   {'node': 'Business',
#    'similarity_rank': 0.0007729124496788622,
#    'label_proba': [0.5486419035605985, 0.45135809643940156],
#    'position': 'after'},
#   {'node': 'Trichuriasis',
#    'similarity_rank': 0.0007728622791398555,
#    'label_proba': [0.41933396689311037, 0.5806660331068898],
#    'position': 'before'},
#   {'node': 'Variance-stabilizing transformation',
#    'similarity_rank': 0.0007723971381336102,
#    'label_proba': [0.49178727158139957, 0.5082127284186004],
#    'position': 'before'},
#   {'node': 'Gender identity',
#    'similarity_rank': 0.0007720979410128222,
#    'label_proba': [0.46602911980112055, 0.5339708801988794],
#    'position': 'before'},
#   {'node': 'Probability',
#    'similarity_rank': 0.0007720919475118585,
#    'label_proba': [0.4015549536206158, 0.5984450463793842],
#    'position': 'before'},
#   {'node': 'Disability-adjusted life year',
#    'similarity_rank': 0.0007720449017145401,
#    'label_proba': [0.41933396689311037, 0.5806660331068898],
#    'position': 'before'},
#   {'node': 'Lassa fever',
#    'similarity_rank': 0.0007720419733077972,
#    'label_proba': [0.45947373677834624, 0.5405262632216538],
#    'position': 'before'},
#   {'node': 'Uncertainty',
#    'similarity_rank': 0.000772004657609854,
#    'label_proba': [0.4761355043870442, 0.5238644956129558],
#    'position': 'before'},
#   {'node': 'Sequential probability ratio test',
#    'similarity_rank': 0.0007719699905703592,
#    'label_proba': [0.44363466327304885, 0.5563653367269512],
#    'position': 'before'},
#   {'node': 'Blood transfusion',
#    'similarity_rank': 0.0007719211167687426,
#    'label_proba': [0.41933396689311037, 0.5806660331068898],
#    'position': 'before'},
#   {'node': 'Glossary of electrical and electronics engineering',
#    'similarity_rank': 0.0007719106599552082,
#    'label_proba': [0.48623705599978884, 0.5137629440002112],
#    'position': 'before'}]}

# %% [markdown]
# # Optional: Format as DataFrame for Easy Viewing

# %%
recommendations = pd.DataFrame(rec.format_results(decision_threshold=0.47)['predictions'])
print(recommendations.position.value_counts())
recommendations
# Out:
# before    52
# after     47
# Name: position, dtype: int64
#                                                  node  similarity_rank  \
# 0                            Detection error tradeoff         0.066241
# 1                               Diagnostic odds ratio         0.045652
# 2                    Net reclassification improvement         0.041333
# 3                           Constant false alarm rate         0.040766
# 4                                   Sensitivity index         0.040713
# ..                                                ...              ...
# 94                                        Lassa fever         0.000772
# 95                                        Uncertainty         0.000772
# 96                  Sequential probability ratio test         0.000772
# 97                                  Blood transfusion         0.000772
# 98  Glossary of electrical and electronics enginee...         0.000772
#
#                                   label_proba position
# 0   [0.48295221130911925, 0.5170477886908806]    after
# 1    [0.5357898564711393, 0.4642101435288606]    after
# 2    [0.6657316763483345, 0.3342683236516654]    after
# 3    [0.5435104298877957, 0.4564895701122042]    after
# 4    [0.5361368750439643, 0.4638631249560356]    after
# ..                                        ...      ...
# 94  [0.45947373677834624, 0.5405262632216538]   before
# 95   [0.4761355043870442, 0.5238644956129558]    after
# 96  [0.44363466327304885, 0.5563653367269512]   before
# 97  [0.41933396689311037, 0.5806660331068898]   before
# 98  [0.48623705599978884, 0.5137629440002112]    after
#
# [99 rows x 4 columns]
