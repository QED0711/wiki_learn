# %% [markdown]
# This notebook shows how to use a `GraphCreator` instance in a recommendation pipeline to easily produce the top recommendations and display their predicted order (before/after)

# %%
# %load_ext autoreload
# %autoreload 1

import sys
sys.path.append('../utils/')

import pickle
import numpy as np
import pandas as pd

from GraphAPI import GraphCreator
from RecommenderPipeline import Recommender

# %aimport GraphAPI
# %aimport RecommenderPipeline

# %% [markdown]
# # Load in Models

# %%
with open("../models/rf_classifier_v2.pkl", "rb") as model:
    rf_classifier = pickle.load(model)
    
with open("../models/xg_model_semisupervised_v2.pkl", "rb") as model:
    xg_classifier = pickle.load(model)

# %% [markdown]
# # Initialize `GraphCreator` Instance
#
# After initialization, pass as an argument to a new recommender instance

# %%
gc = GraphCreator("Random forest")

rec = Recommender(gc)

# %% [markdown]
# # Fit the Recommender

# %%
rec.fit()

# %% [markdown]
# # Make Predictions
# Pass in your model to make predictions on the data

# %%
rec.predict(rf_classifier)
# rec.predict(xg_classifier)

# %% [markdown]
# # Format the Results
# Will return as a dictionary containing the entry node and the predictions of the top articles.

# %%
rec.format_results()
# Out:
# {'entry': 'Random forest',
#  'predictions': [{'node': 'Gradient boosting',
#    'similarity_rank': 0.4629312240830749,
#    'label_proba': [0.6152191681287082, 0.3847808318712916],
#    'position': 'after'},
#   {'node': 'Bootstrap aggregating',
#    'similarity_rank': 0.36334365644162603,
#    'label_proba': [0.6556097534621095, 0.34439024653789024],
#    'position': 'after'},
#   {'node': 'Random subspace method',
#    'similarity_rank': 0.35118901548815384,
#    'label_proba': [0.546979258272133, 0.4530207417278669],
#    'position': 'after'},
#   {'node': 'Boosting (machine learning)',
#    'similarity_rank': 0.3421308783981287,
#    'label_proba': [0.6518065652357944, 0.34819343476420533],
#    'position': 'after'},
#   {'node': 'Decision tree learning',
#    'similarity_rank': 0.3314717857532199,
#    'label_proba': [0.6713333426792982, 0.32866665732070155],
#    'position': 'after'},
#   {'node': 'Out-of-bag error',
#    'similarity_rank': 0.2600665165267665,
#    'label_proba': [0.606178854079004, 0.39382114592099593],
#    'position': 'after'},
#   {'node': 'Ensemble learning',
#    'similarity_rank': 0.23911464882264144,
#    'label_proba': [0.6518065652357944, 0.34819343476420533],
#    'position': 'after'},
#   {'node': 'Statistical classification',
#    'similarity_rank': 0.2060956547704899,
#    'label_proba': [0.48602124426395155, 0.5139787557360485],
#    'position': 'before'},
#   {'node': 'Logic learning machine',
#    'similarity_rank': 0.17723036637093145,
#    'label_proba': [0.5937373202477917, 0.4062626797522082],
#    'position': 'after'},
#   {'node': 'Occam learning',
#    'similarity_rank': 0.1721867407338417,
#    'label_proba': [0.6362680302524217, 0.3637319697475779],
#    'position': 'after'},
#   {'node': 'AdaBoost',
#    'similarity_rank': 0.17062880011574644,
#    'label_proba': [0.6179064552428075, 0.3820935447571924],
#    'position': 'after'},
#   {'node': 'Relevance vector machine',
#    'similarity_rank': 0.16834466307678572,
#    'label_proba': [0.6470570743637143, 0.35294292563628543],
#    'position': 'after'},
#   {'node': 'Feature engineering',
#    'similarity_rank': 0.16783646422269594,
#    'label_proba': [0.6043199079104666, 0.39568009208953314],
#    'position': 'after'},
#   {'node': 'Empirical risk minimization',
#    'similarity_rank': 0.1639010538756637,
#    'label_proba': [0.651912998898215, 0.34808700110178475],
#    'position': 'after'},
#   {'node': 'Automated machine learning',
#    'similarity_rank': 0.16269128211022316,
#    'label_proba': [0.6494618204470365, 0.35053817955296324],
#    'position': 'after'},
#   {'node': 'Bias–variance tradeoff',
#    'similarity_rank': 0.16172386264801702,
#    'label_proba': [0.6494618204470365, 0.35053817955296324],
#    'position': 'after'},
#   {'node': 'Feature learning',
#    'similarity_rank': 0.16118210437075497,
#    'label_proba': [0.651912998898215, 0.34808700110178475],
#    'position': 'after'},
#   {'node': 'Semi-supervised learning',
#    'similarity_rank': 0.1596567545330865,
#    'label_proba': [0.6450772436511578, 0.35492275634884196],
#    'position': 'after'},
#   {'node': 'Anomaly detection',
#    'similarity_rank': 0.158878370545584,
#    'label_proba': [0.6087030433035293, 0.39129695669647047],
#    'position': 'after'},
#   {'node': 'Multilayer perceptron',
#    'similarity_rank': 0.1571859093343262,
#    'label_proba': [0.6503316904869999, 0.34966830951299976],
#    'position': 'after'},
#   {'node': 'Statistical learning theory',
#    'similarity_rank': 0.15483452791353358,
#    'label_proba': [0.6450772436511578, 0.35492275634884196],
#    'position': 'after'},
#   {'node': 'K-nearest neighbors algorithm',
#    'similarity_rank': 0.15403069248432444,
#    'label_proba': [0.6289326959445121, 0.3710673040554877],
#    'position': 'after'},
#   {'node': 'Conditional random field',
#    'similarity_rank': 0.15337978420654483,
#    'label_proba': [0.6092183176386269, 0.39078168236137295],
#    'position': 'after'},
#   {'node': 'Overfitting',
#    'similarity_rank': 0.15195657442542715,
#    'label_proba': [0.6099438403368833, 0.39005615966311646],
#    'position': 'after'},
#   {'node': 'Learning to rank',
#    'similarity_rank': 0.1517497587469994,
#    'label_proba': [0.5453337086170957, 0.4546662913829041],
#    'position': 'after'},
#   {'node': 'Support-vector machine',
#    'similarity_rank': 0.15073016566360026,
#    'label_proba': [0.6464249140810036, 0.3535750859189962],
#    'position': 'after'},
#   {'node': 'Grammar induction',
#    'similarity_rank': 0.14998813797916216,
#    'label_proba': [0.6456586322207214, 0.3543413677792783],
#    'position': 'after'},
#   {'node': 'Computational learning theory',
#    'similarity_rank': 0.14884894357606376,
#    'label_proba': [0.6089148369578169, 0.3910851630421828],
#    'position': 'after'},
#   {'node': 'List of datasets for machine-learning research',
#    'similarity_rank': 0.1459531996038741,
#    'label_proba': [0.6443274228509975, 0.35567257714900213],
#    'position': 'after'},
#   {'node': 'Perceptron',
#    'similarity_rank': 0.1436048085271341,
#    'label_proba': [0.6359026742754241, 0.36409732572457565],
#    'position': 'after'},
#   {'node': 'Naive Bayes classifier',
#    'similarity_rank': 0.1426574734951541,
#    'label_proba': [0.6440926430094425, 0.3559073569905574],
#    'position': 'after'},
#   {'node': 'Dimensionality reduction',
#    'similarity_rank': 0.14117983696202668,
#    'label_proba': [0.6359026742754241, 0.36409732572457565],
#    'position': 'after'},
#   {'node': 'Kernel method',
#    'similarity_rank': 0.13855546760936102,
#    'label_proba': [0.6434023396030242, 0.3565976603969757],
#    'position': 'after'},
#   {'node': 'Artificial neural network',
#    'similarity_rank': 0.13664160831042807,
#    'label_proba': [0.46518269923558614, 0.5348173007644139],
#    'position': 'before'},
#   {'node': 'Convolutional neural network',
#    'similarity_rank': 0.12289265094485145,
#    'label_proba': [0.5763423087148151, 0.4236576912851848],
#    'position': 'after'},
#   {'node': 'Unsupervised learning',
#    'similarity_rank': 0.12138773782634275,
#    'label_proba': [0.4701215346291378, 0.5298784653708621],
#    'position': 'before'},
#   {'node': 'Leo Breiman',
#    'similarity_rank': 0.11811233498569404,
#    'label_proba': [0.5215159765867649, 0.47848402341323504],
#    'position': 'after'},
#   {'node': 'Tin Kam Ho',
#    'similarity_rank': 0.11746809453178232,
#    'label_proba': [0.5384076379179478, 0.46159236208205223],
#    'position': 'after'},
#   {'node': 'Adele Cutler',
#    'similarity_rank': 0.11745470220707846,
#    'label_proba': [0.5056506540737604, 0.49434934592623947],
#    'position': 'after'},
#   {'node': 'Supervised learning',
#    'similarity_rank': 0.11727968325021525,
#    'label_proba': [0.49758272676632004, 0.50241727323368],
#    'position': 'before'},
#   {'node': 'Donald Geman',
#    'similarity_rank': 0.11611893026054755,
#    'label_proba': [0.5476849895471492, 0.4523150104528508],
#    'position': 'after'},
#   {'node': 'Machine Learning (journal)',
#    'similarity_rank': 0.11532705623949376,
#    'label_proba': [0.5064519887672145, 0.49354801123278547],
#    'position': 'after'},
#   {'node': 'Journal of Machine Learning Research',
#    'similarity_rank': 0.10700762114755005,
#    'label_proba': [0.5064519887672145, 0.49354801123278547],
#    'position': 'after'},
#   {'node': 'Decision tree',
#    'similarity_rank': 0.10495776119074118,
#    'label_proba': [0.5056901090625483, 0.49430989093745176],
#    'position': 'after'},
#   {'node': 'Multiple instance learning',
#    'similarity_rank': 0.10459431145563308,
#    'label_proba': [0.6002553801033128, 0.399744619896687],
#    'position': 'after'},
#   {'node': 'Labeled data',
#    'similarity_rank': 0.10383719861748256,
#    'label_proba': [0.601765867295629, 0.3982341327043709],
#    'position': 'after'},
#   {'node': 'Model-free (reinforcement learning)',
#    'similarity_rank': 0.10349803699312447,
#    'label_proba': [0.6030163890930096, 0.3969836109069903],
#    'position': 'after'},
#   {'node': 'Error tolerance (PAC learning)',
#    'similarity_rank': 0.10312220039572775,
#    'label_proba': [0.606178854079004, 0.39382114592099593],
#    'position': 'after'},
#   {'node': 'Logistic model tree',
#    'similarity_rank': 0.10305244534099049,
#    'label_proba': [0.6020643839119022, 0.3979356160880977],
#    'position': 'after'},
#   {'node': 'Feature scaling',
#    'similarity_rank': 0.1027154970777932,
#    'label_proba': [0.6009756248012702, 0.39902437519872963],
#    'position': 'after'},
#   {'node': 'Sample complexity',
#    'similarity_rank': 0.10253671338677446,
#    'label_proba': [0.5938586657369427, 0.40614133426305715],
#    'position': 'after'},
#   {'node': 'Active learning (machine learning)',
#    'similarity_rank': 0.10235713708897036,
#    'label_proba': [0.5871126928303029, 0.412887307169697],
#    'position': 'after'},
#   {'node': 'Action model learning',
#    'similarity_rank': 0.10182444077323308,
#    'label_proba': [0.6204657362698761, 0.3795342637301237],
#    'position': 'after'},
#   {'node': 'Learning rate',
#    'similarity_rank': 0.1008205636844906,
#    'label_proba': [0.5879279842602293, 0.41207201573977054],
#    'position': 'after'},
#   {'node': 'Vanishing gradient problem',
#    'similarity_rank': 0.10035690971590028,
#    'label_proba': [0.6291847031227153, 0.37081529687728454],
#    'position': 'after'},
#   {'node': 'Sparse dictionary learning',
#    'similarity_rank': 0.09849304801429856,
#    'label_proba': [0.6358861308114924, 0.36411386918850747],
#    'position': 'after'},
#   {'node': 'Caffe (software)',
#    'similarity_rank': 0.095737896130033,
#    'label_proba': [0.6323962050216009, 0.36760379497839907],
#    'position': 'after'},
#   {'node': 'Linear discriminant analysis',
#    'similarity_rank': 0.09388003668756265,
#    'label_proba': [0.4826941618852845, 0.5173058381147155],
#    'position': 'before'},
#   {'node': 'Deeplearning4j',
#    'similarity_rank': 0.0908655441403266,
#    'label_proba': [0.6601114314766799, 0.3398885685233201],
#    'position': 'after'},
#   {'node': 'Word2vec',
#    'similarity_rank': 0.09038216720803342,
#    'label_proba': [0.6248937446616268, 0.37510625533837305],
#    'position': 'after'},
#   {'node': 'Training, validation, and test sets',
#    'similarity_rank': 0.08820613312982624,
#    'label_proba': [0.5372268740197618, 0.46277312598023806],
#    'position': 'after'},
#   {'node': 'Feature (machine learning)',
#    'similarity_rank': 0.08664156615618791,
#    'label_proba': [0.5468769771748011, 0.45312302282519856],
#    'position': 'after'},
#   {'node': 'Generalization error',
#    'similarity_rank': 0.08099229076681651,
#    'label_proba': [0.5282957251235807, 0.47170427487641925],
#    'position': 'after'},
#   {'node': 'Machine learning in bioinformatics',
#    'similarity_rank': 0.08050493752921864,
#    'label_proba': [0.5778820975491269, 0.422117902450873],
#    'position': 'after'},
#   {'node': 'Timeline of machine learning',
#    'similarity_rank': 0.07991522821249346,
#    'label_proba': [0.617654637116854, 0.3823453628831459],
#    'position': 'after'},
#   {'node': 'Jackknife variance estimates for random forest',
#    'similarity_rank': 0.0787408404858796,
#    'label_proba': [0.4942079752057289, 0.5057920247942711],
#    'position': 'before'},
#   {'node': 'Learning curve (machine learning)',
#    'similarity_rank': 0.0784756629292562,
#    'label_proba': [0.6037267321584112, 0.39627326784158856],
#    'position': 'after'},
#   {'node': 'Multinomial logistic regression',
#    'similarity_rank': 0.07745994096646815,
#    'label_proba': [0.6267888762502188, 0.37321112374978105],
#    'position': 'after'},
#   {'node': 'Outline of machine learning',
#    'similarity_rank': 0.07613360993819139,
#    'label_proba': [0.6179469736683574, 0.3820530263316423],
#    'position': 'after'},
#   {'node': 'Discriminative model',
#    'similarity_rank': 0.07591845267149724,
#    'label_proba': [0.6125719721529767, 0.38742802784702335],
#    'position': 'after'},
#   {'node': 'Generative model',
#    'similarity_rank': 0.07448433468228097,
#    'label_proba': [0.6263904023888975, 0.37360959761110224],
#    'position': 'after'},
#   {'node': 'Mean shift',
#    'similarity_rank': 0.0727992147087371,
#    'label_proba': [0.6556097534621095, 0.34439024653789024],
#    'position': 'after'},
#   {'node': 'State–action–reward–state–action',
#    'similarity_rank': 0.07207141087186344,
#    'label_proba': [0.6399647848163164, 0.36003521518368337],
#    'position': 'after'},
#   {'node': 'CURE algorithm',
#    'similarity_rank': 0.07161892716952788,
#    'label_proba': [0.6347563363608404, 0.36524366363915944],
#    'position': 'after'},
#   {'node': 'Local outlier factor',
#    'similarity_rank': 0.07071699169860383,
#    'label_proba': [0.6431272498023106, 0.356872750197689],
#    'position': 'after'},
#   {'node': 'U-Net',
#    'similarity_rank': 0.07034312521253559,
#    'label_proba': [0.6431272498023106, 0.356872750197689],
#    'position': 'after'},
#   {'node': 'BIRCH',
#    'similarity_rank': 0.0687296545460655,
#    'label_proba': [0.6431272498023106, 0.356872750197689],
#    'position': 'after'},
#   {'node': 'Regression analysis',
#    'similarity_rank': 0.06865057398207479,
#    'label_proba': [0.39727003687438306, 0.602729963125617],
#    'position': 'before'},
#   {'node': 'OPTICS algorithm',
#    'similarity_rank': 0.06863056711237066,
#    'label_proba': [0.6556097534621095, 0.34439024653789024],
#    'position': 'after'},
#   {'node': 'Temporal difference learning',
#    'similarity_rank': 0.06798248314360497,
#    'label_proba': [0.6466585520623727, 0.35334144793762695],
#    'position': 'after'},
#   {'node': 'Pattern recognition',
#    'similarity_rank': 0.06763109692179745,
#    'label_proba': [0.48170708155875686, 0.518292918441243],
#    'position': 'before'},
#   {'node': 'T-distributed stochastic neighbor embedding',
#    'similarity_rank': 0.06729711490656042,
#    'label_proba': [0.6556097534621095, 0.34439024653789024],
#    'position': 'after'},
#   {'node': 'Q-learning',
#    'similarity_rank': 0.06606338716343844,
#    'label_proba': [0.6556097534621095, 0.34439024653789024],
#    'position': 'after'},
#   {'node': 'Randomized algorithm',
#    'similarity_rank': 0.06589633971223234,
#    'label_proba': [0.44751411341620945, 0.5524858865837907],
#    'position': 'before'},
#   {'node': 'DBSCAN',
#    'similarity_rank': 0.06513845498640326,
#    'label_proba': [0.6556097534621095, 0.34439024653789024],
#    'position': 'after'},
#   {'node': 'Probably approximately correct learning',
#    'similarity_rank': 0.0639855311326698,
#    'label_proba': [0.6470570743637143, 0.35294292563628543],
#    'position': 'after'},
#   {'node': 'Cross-validation (statistics)',
#    'similarity_rank': 0.06368171427405087,
#    'label_proba': [0.49990242703965954, 0.5000975729603404],
#    'position': 'before'},
#   {'node': 'International Conference on Machine Learning',
#    'similarity_rank': 0.06334924267850377,
#    'label_proba': [0.6431272498023106, 0.356872750197689],
#    'position': 'after'},
#   {'node': 'DeepDream',
#    'similarity_rank': 0.06327280037646058,
#    'label_proba': [0.6556097534621095, 0.34439024653789024],
#    'position': 'after'},
#   {'node': 'Mode (statistics)',
#    'similarity_rank': 0.06180191726521788,
#    'label_proba': [0.5179320767083933, 0.48206792329160686],
#    'position': 'after'},
#   {'node': 'Restricted Boltzmann machine',
#    'similarity_rank': 0.061649039383930467,
#    'label_proba': [0.6478805120358215, 0.35211948796417825],
#    'position': 'after'},
#   {'node': 'Vapnik–Chervonenkis theory',
#    'similarity_rank': 0.0614940732379236,
#    'label_proba': [0.6556097534621095, 0.34439024653789024],
#    'position': 'after'},
#   {'node': 'Autoencoder',
#    'similarity_rank': 0.0611896104867943,
#    'label_proba': [0.6556097534621095, 0.34439024653789024],
#    'position': 'after'},
#   {'node': 'Association rule learning',
#    'similarity_rank': 0.06084264845410883,
#    'label_proba': [0.651577266599716, 0.3484227334002837],
#    'position': 'after'},
#   {'node': 'Structured prediction',
#    'similarity_rank': 0.060760837535691455,
#    'label_proba': [0.6556097534621095, 0.34439024653789024],
#    'position': 'after'},
#   {'node': 'Online machine learning',
#    'similarity_rank': 0.060067560522196965,
#    'label_proba': [0.6540284450508946, 0.34597155494910525],
#    'position': 'after'},
#   {'node': 'Generative adversarial network',
#    'similarity_rank': 0.0597249654453714,
#    'label_proba': [0.6556097534621095, 0.34439024653789024],
#    'position': 'after'},
#   {'node': 'Minitab',
#    'similarity_rank': 0.05504921279899997,
#    'label_proba': [0.4806627773878237, 0.5193372226121764],
#    'position': 'before'},
#   {'node': 'Long short-term memory',
#    'similarity_rank': 0.05488369841616531,
#    'label_proba': [0.663867497607518, 0.3361325023924818],
#    'position': 'after'}]}

# %% [markdown]
# # Optional: Format as DataFrame for Easy Viewing

# %%
pd.DataFrame(rec.format_results(decision_threshold=0.64)['predictions']).position.value_counts()
# Out:
# before    61
# after     38
# Name: position, dtype: int64
