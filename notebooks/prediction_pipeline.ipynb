# %% [markdown]
# This notebook shows how to use a `GraphCreator` instance in a recommendation pipeline to easily produce the top recommendations and display their predicted order (before/after)

# %%
# %load_ext autoreload
# %autoreload 1

import sys
sys.path.append('../utils/')

import pickle
import numpy as np
import pandas as pd

from GraphAPI import GraphCreator
from RecommenderPipeline import Recommender

from sklearn.preprocessing import normalize, StandardScaler, Normalizer, RobustScaler, MinMaxScaler, MaxAbsScaler


# %aimport GraphAPI
# %aimport RecommenderPipeline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Load in Models

# %%
with open("../models/rf_classifier_v2_normalized.pkl", "rb") as model:
    rf_classifier = pickle.load(model)
    
with open("../models/xg_model_semisupervised_v2.pkl", "rb") as model:
    xg_classifier = pickle.load(model)

# %% [markdown]
# # Initialize `GraphCreator` Instance
#
# After initialization, pass as an argument to a new recommender instance

# %%
gc = GraphCreator("Music theory")
print("Layer 1 nodes:", len(gc.graph.nodes))
rec = Recommender(gc)
# Out:
# Layer 1 nodes: 2185

# %% [markdown]
# # Fit the Recommender

# %%
rec.fit(scaler=Normalizer)

# %% [markdown]
# # Make Predictions
# Pass in your model to make predictions on the data

# %%
rec.predict(rf_classifier)
# rec.predict(xg_classifier)

# %% [markdown]
# # Format the Results
# Will return as a dictionary containing the entry node and the predictions of the top articles.

# %%
rec.format_results()
# Out:
# {'entry': 'Music theory',
#  'decision_threshold': 0.5600000000000003,
#  'predictions': [{'node': 'Dickinson classification',
#    'similarity_rank': 0.037197024018502826,
#    'label_proba': [0.5561503452415255, 0.44384965475847443],
#    'position': 'before'},
#   {'node': 'Ian Bent',
#    'similarity_rank': 0.027839411620091757,
#    'label_proba': [0.6268176412977112, 0.3731823587022889],
#    'position': 'after'},
#   {'node': 'Transformational theory',
#    'similarity_rank': 0.022601519434496706,
#    'label_proba': [0.5508630971012216, 0.4491369028987782],
#    'position': 'before'},
#   {'node': 'Tune-family',
#    'similarity_rank': 0.02226056248263427,
#    'label_proba': [0.6146794670171444, 0.38532053298285573],
#    'position': 'after'},
#   {'node': 'Society for Music Theory',
#    'similarity_rank': 0.018983058671615444,
#    'label_proba': [0.5240626858470828, 0.475937314152917],
#    'position': 'before'},
#   {'node': 'Musicology in Cuba',
#    'similarity_rank': 0.018579619750610826,
#    'label_proba': [0.7040553595002068, 0.295944640499793],
#    'position': 'after'},
#   {'node': 'Scolica enchiriadis',
#    'similarity_rank': 0.016218670363351628,
#    'label_proba': [0.5616173851831704, 0.4383826148168295],
#    'position': 'after'},
#   {'node': 'Spiral array model',
#    'similarity_rank': 0.015053057668971064,
#    'label_proba': [0.5928486174606348, 0.4071513825393652],
#    'position': 'after'},
#   {'node': 'Cenobio Paniagua',
#    'similarity_rank': 0.014040884279525115,
#    'label_proba': [0.7191799763666609, 0.28082002363333897],
#    'position': 'after'},
#   {'node': 'Giovanni Paolo Foscarini',
#    'similarity_rank': 0.01388573416152317,
#    'label_proba': [0.657533963999598, 0.34246603600040204],
#    'position': 'after'},
#   {'node': 'John Caldwell (musicologist)',
#    'similarity_rank': 0.013501108797264696,
#    'label_proba': [0.6873784981193332, 0.31262150188066684],
#    'position': 'after'},
#   {'node': 'Music semiology',
#    'similarity_rank': 0.010724339440209632,
#    'label_proba': [0.586038525337528, 0.41396147466247185],
#    'position': 'after'},
#   {'node': 'Euclidean rhythm',
#    'similarity_rank': 0.008705008518430863,
#    'label_proba': [0.7005631684363073, 0.29943683156369255],
#    'position': 'after'},
#   {'node': 'Kodály method',
#    'similarity_rank': 0.008681209988221073,
#    'label_proba': [0.6276912729851455, 0.3723087270148546],
#    'position': 'after'},
#   {'node': 'Musical tone',
#    'similarity_rank': 0.008178248343676302,
#    'label_proba': [0.5832574050302077, 0.416742594969792],
#    'position': 'after'},
#   {'node': 'Octave species',
#    'similarity_rank': 0.0077515243073342155,
#    'label_proba': [0.6193438042595103, 0.38065619574048976],
#    'position': 'after'},
#   {'node': 'William Edwin Haesche',
#    'similarity_rank': 0.007662751103054951,
#    'label_proba': [0.7230870437277477, 0.2769129562722522],
#    'position': 'after'},
#   {'node': 'Diatonic set theory',
#    'similarity_rank': 0.007453758165988465,
#    'label_proba': [0.5631326981449373, 0.43686730185506273],
#    'position': 'after'},
#   {'node': 'Neo-Riemannian theory',
#    'similarity_rank': 0.006818006987849836,
#    'label_proba': [0.6860792300612654, 0.3139207699387343],
#    'position': 'after'},
#   {'node': 'Tension (music)',
#    'similarity_rank': 0.004653542109415926,
#    'label_proba': [0.6611507126834555, 0.3388492873165447],
#    'position': 'after'},
#   {'node': 'Jean Titelouze',
#    'similarity_rank': 0.004556402120335814,
#    'label_proba': [0.6874764541550162, 0.31252354584498365],
#    'position': 'after'},
#   {'node': 'Iván Erőd',
#    'similarity_rank': 0.003996709674710231,
#    'label_proba': [0.66828673706638, 0.33171326293362013],
#    'position': 'after'},
#   {'node': 'Johannes Regis',
#    'similarity_rank': 0.003505885211929522,
#    'label_proba': [0.6475550187150304, 0.3524449812849697],
#    'position': 'after'},
#   {'node': 'Guido of Arezzo',
#    'similarity_rank': 0.003415226860134401,
#    'label_proba': [0.533683110159672, 0.4663168898403278],
#    'position': 'before'},
#   {'node': 'Musical argument',
#    'similarity_rank': 0.003346287358799728,
#    'label_proba': [0.5891233475313474, 0.4108766524686526],
#    'position': 'after'},
#   {'node': 'Constant structure',
#    'similarity_rank': 0.003324897452633528,
#    'label_proba': [0.5586121840376561, 0.44138781596234383],
#    'position': 'before'},
#   {'node': 'AP Music Theory',
#    'similarity_rank': 0.0032885015369709743,
#    'label_proba': [0.44454466700915174, 0.5554553329908483],
#    'position': 'before'},
#   {'node': 'List of chord progressions',
#    'similarity_rank': 0.0032880254083123236,
#    'label_proba': [0.5539446449770037, 0.44605535502299626],
#    'position': 'before'},
#   {'node': 'Theory of painting',
#    'similarity_rank': 0.0029886452751996823,
#    'label_proba': [0.47686919337107697, 0.5231308066289229],
#    'position': 'before'},
#   {'node': 'Lyric Suite (Berg)',
#    'similarity_rank': 0.0029855775566516207,
#    'label_proba': [0.6217632600348613, 0.3782367399651387],
#    'position': 'after'},
#   {'node': 'French classical music',
#    'similarity_rank': 0.002913659642123627,
#    'label_proba': [0.6453376126398763, 0.3546623873601235],
#    'position': 'after'},
#   {'node': 'Chinese musicology',
#    'similarity_rank': 0.002834748263804978,
#    'label_proba': [0.5050919245908967, 0.4949080754091033],
#    'position': 'before'},
#   {'node': 'Augmentation (music)',
#    'similarity_rank': 0.0028089475326944554,
#    'label_proba': [0.5058224746894379, 0.494177525310562],
#    'position': 'before'},
#   {'node': 'Generative theory of tonal music',
#    'similarity_rank': 0.0027108479516952852,
#    'label_proba': [0.6062365954435106, 0.39376340455648945],
#    'position': 'after'},
#   {'node': 'Robert Fuchs',
#    'similarity_rank': 0.0025562348000635927,
#    'label_proba': [0.5573525790481741, 0.44264742095182563],
#    'position': 'before'},
#   {'node': 'Roman numeral analysis',
#    'similarity_rank': 0.002515257453151265,
#    'label_proba': [0.5605811481542733, 0.4394188518457266],
#    'position': 'after'},
#   {'node': 'Musical gesture',
#    'similarity_rank': 0.002502845959463654,
#    'label_proba': [0.6014864164878146, 0.3985135835121855],
#    'position': 'after'},
#   {'node': 'Edmund Rice (colonist)',
#    'similarity_rank': 0.0024127011271704857,
#    'label_proba': [0.6764899263135378, 0.32351007368646245],
#    'position': 'after'},
#   {'node': 'List of musical scales and modes',
#    'similarity_rank': 0.002393820737218481,
#    'label_proba': [0.5506928074916809, 0.44930719250831896],
#    'position': 'before'},
#   {'node': 'Tertian',
#    'similarity_rank': 0.0023863623019584027,
#    'label_proba': [0.5685379753515207, 0.43146202464847927],
#    'position': 'after'},
#   {'node': 'Inversion (music)',
#    'similarity_rank': 0.002221218004993617,
#    'label_proba': [0.5946012350582984, 0.4053987649417015],
#    'position': 'after'},
#   {'node': 'Hemiola',
#    'similarity_rank': 0.002191415341075691,
#    'label_proba': [0.6550089355700923, 0.34499106442990723],
#    'position': 'after'},
#   {'node': 'List of music theorists',
#    'similarity_rank': 0.002079341792072393,
#    'label_proba': [0.6827037475743457, 0.31729625242565407],
#    'position': 'after'},
#   {'node': 'Texture (music)',
#    'similarity_rank': 0.002059355579076057,
#    'label_proba': [0.5436656199218732, 0.45633438007812643],
#    'position': 'before'},
#   {'node': 'List of chords',
#    'similarity_rank': 0.0020342937944308904,
#    'label_proba': [0.5632670393909297, 0.4367329606090704],
#    'position': 'after'},
#   {'node': 'Style brisé',
#    'similarity_rank': 0.001924168437387445,
#    'label_proba': [0.6877188637077353, 0.3122811362922644],
#    'position': 'after'},
#   {'node': 'Music history',
#    'similarity_rank': 0.0018116836721549679,
#    'label_proba': [0.5632778432065585, 0.43672215679344156],
#    'position': 'after'},
#   {'node': 'Art music',
#    'similarity_rank': 0.001759276718065396,
#    'label_proba': [0.5151646584868007, 0.4848353415131992],
#    'position': 'before'},
#   {'node': 'Cognitive musicology',
#    'similarity_rank': 0.0016935053635227996,
#    'label_proba': [0.4480540815027237, 0.5519459184972764],
#    'position': 'before'},
#   {'node': 'Doctor of Musical Arts',
#    'similarity_rank': 0.0015176691158681871,
#    'label_proba': [0.5212332432881455, 0.47876675671185437],
#    'position': 'before'},
#   {'node': 'Mensural notation',
#    'similarity_rank': 0.0014949978494715758,
#    'label_proba': [0.5205197392622437, 0.4794802607377562],
#    'position': 'before'},
#   {'node': 'Adrian Willaert',
#    'similarity_rank': 0.0014589346490066044,
#    'label_proba': [0.5216205047567987, 0.4783794952432013],
#    'position': 'before'},
#   {'node': 'Computational musicology',
#    'similarity_rank': 0.0014455667107370262,
#    'label_proba': [0.5801260213249914, 0.41987397867500836],
#    'position': 'after'},
#   {'node': 'Portato',
#    'similarity_rank': 0.0014431042752634184,
#    'label_proba': [0.6570141129266719, 0.34298588707332806],
#    'position': 'after'},
#   {'node': 'New musicology',
#    'similarity_rank': 0.001425081879287364,
#    'label_proba': [0.5698952520942222, 0.4301047479057777],
#    'position': 'after'},
#   {'node': 'Neapolitan chord',
#    'similarity_rank': 0.0014181619162835063,
#    'label_proba': [0.5651308779974707, 0.4348691220025293],
#    'position': 'after'},
#   {'node': 'Leevi Madetoja',
#    'similarity_rank': 0.0013748106812443142,
#    'label_proba': [0.6317434279462307, 0.3682565720537692],
#    'position': 'after'},
#   {'node': 'Staff (music)',
#    'similarity_rank': 0.0013268820932527876,
#    'label_proba': [0.4907864778387565, 0.5092135221612434],
#    'position': 'before'},
#   {'node': 'History of music',
#    'similarity_rank': 0.0011870396130323937,
#    'label_proba': [0.5719742060821097, 0.4280257939178903],
#    'position': 'after'},
#   {'node': 'History of music in the biblical period',
#    'similarity_rank': 0.001186160981769012,
#    'label_proba': [0.6002420577233998, 0.39975794227660005],
#    'position': 'after'},
#   {'node': 'Music and politics',
#    'similarity_rank': 0.0010994986736668456,
#    'label_proba': [0.6300644503791826, 0.36993554962081737],
#    'position': 'after'},
#   {'node': 'Octatonic scale',
#    'similarity_rank': 0.0010922623431877544,
#    'label_proba': [0.6084980194716116, 0.3915019805283883],
#    'position': 'after'},
#   {'node': 'Postmodern music',
#    'similarity_rank': 0.0010814324764819169,
#    'label_proba': [0.5115381389312492, 0.4884618610687508],
#    'position': 'before'},
#   {'node': 'Ecomusicology',
#    'similarity_rank': 0.0010463792888611987,
#    'label_proba': [0.5258832127230679, 0.4741167872769321],
#    'position': 'before'},
#   {'node': 'Canon (music)',
#    'similarity_rank': 0.0008618018321882856,
#    'label_proba': [0.5527731375562481, 0.44722686244375154],
#    'position': 'before'},
#   {'node': 'Toru Takemitsu',
#    'similarity_rank': 0.0008288479376633931,
#    'label_proba': [0.6147353494161091, 0.38526465058389087],
#    'position': 'after'},
#   {'node': 'Chord (music)',
#    'similarity_rank': 0.0008193529015924534,
#    'label_proba': [0.5021224985202393, 0.4978775014797608],
#    'position': 'before'},
#   {'node': 'Anton Reicha',
#    'similarity_rank': 0.0008171562889482282,
#    'label_proba': [0.5806211544010427, 0.419378845598957],
#    'position': 'after'},
#   {'node': 'Scale (music)',
#    'similarity_rank': 0.0008123135766667897,
#    'label_proba': [0.4269525383359284, 0.5730474616640717],
#    'position': 'before'},
#   {'node': 'Music psychology',
#    'similarity_rank': 0.0007770206662089026,
#    'label_proba': [0.5313996564682999, 0.4686003435317001],
#    'position': 'before'},
#   {'node': 'Music technology (electric)',
#    'similarity_rank': 0.0007336363252638611,
#    'label_proba': [0.504986091237289, 0.495013908762711],
#    'position': 'before'},
#   {'node': 'Music of Trinidad and Tobago',
#    'similarity_rank': 0.0007256060614167287,
#    'label_proba': [0.5788465733079164, 0.42115342669208344],
#    'position': 'after'},
#   {'node': 'Glossary of musical terminology',
#    'similarity_rank': 0.000685467747244068,
#    'label_proba': [0.4895279402251258, 0.5104720597748742],
#    'position': 'before'},
#   {'node': 'Pentatonic scale',
#    'similarity_rank': 0.0006752237895173989,
#    'label_proba': [0.5075228702872439, 0.4924771297127561],
#    'position': 'before'},
#   {'node': 'Music technology (electronic and digital)',
#    'similarity_rank': 0.0006670918119837437,
#    'label_proba': [0.5065126444448182, 0.4934873555551818],
#    'position': 'before'},
#   {'node': 'Music of Malawi',
#    'similarity_rank': 0.0006189211443624905,
#    'label_proba': [0.471112765747566, 0.528887234252434],
#    'position': 'before'},
#   {'node': 'Musicology',
#    'similarity_rank': 0.0005883049446763146,
#    'label_proba': [0.4164550075008947, 0.5835449924991054],
#    'position': 'before'},
#   {'node': 'Mode (music)',
#    'similarity_rank': 0.0005846679454773179,
#    'label_proba': [0.46322172123782734, 0.5367782787621728],
#    'position': 'before'},
#   {'node': 'Interval (music)',
#    'similarity_rank': 0.0005807765252139481,
#    'label_proba': [0.40433697923886663, 0.5956630207611334],
#    'position': 'before'},
#   {'node': 'Madrigal',
#    'similarity_rank': 0.0005748942700976439,
#    'label_proba': [0.5749044738105854, 0.4250955261894147],
#    'position': 'after'},
#   {'node': 'Music of Jamaica',
#    'similarity_rank': 0.0005548194797611862,
#    'label_proba': [0.4368278756640086, 0.5631721243359913],
#    'position': 'before'},
#   {'node': 'Music learning theory',
#    'similarity_rank': 0.0005248256673764663,
#    'label_proba': [0.6152420352574426, 0.38475796474255763],
#    'position': 'after'},
#   {'node': 'List of Caribbean music genres',
#    'similarity_rank': 0.0005144089477049216,
#    'label_proba': [0.49977156659074917, 0.5002284334092508],
#    'position': 'before'},
#   {'node': 'Music of Belgium',
#    'similarity_rank': 0.0005022164029881084,
#    'label_proba': [0.44956186947646537, 0.5504381305235346],
#    'position': 'before'},
#   {'node': 'Paleolithic flutes',
#    'similarity_rank': 0.0004972109862024076,
#    'label_proba': [0.4287338620023229, 0.5712661379976772],
#    'position': 'before'},
#   {'node': 'Minimal music',
#    'similarity_rank': 0.00045272143925059044,
#    'label_proba': [0.41015405547383404, 0.589845944526166],
#    'position': 'before'},
#   {'node': 'Humour',
#    'similarity_rank': 0.00045075099588917514,
#    'label_proba': [0.42744287365940586, 0.5725571263405941],
#    'position': 'before'},
#   {'node': 'ISO 80000-1',
#    'similarity_rank': 0.0004351249076191343,
#    'label_proba': [0.5153831984557303, 0.4846168015442695],
#    'position': 'before'},
#   {'node': 'Progressive rock',
#    'similarity_rank': 0.0004280263773589246,
#    'label_proba': [0.4930905377042521, 0.506909462295748],
#    'position': 'before'},
#   {'node': 'Songwriter',
#    'similarity_rank': 0.0004215643524587009,
#    'label_proba': [0.3932145997241209, 0.6067854002758792],
#    'position': 'before'},
#   {'node': 'Women in music',
#    'similarity_rank': 0.00041965661643622506,
#    'label_proba': [0.4129210103855018, 0.5870789896144983],
#    'position': 'before'},
#   {'node': 'Classical period (music)',
#    'similarity_rank': 0.00041665336127113173,
#    'label_proba': [0.4338203067937711, 0.5661796932062287],
#    'position': 'before'},
#   {'node': 'Syncopation',
#    'similarity_rank': 0.00041193577113683385,
#    'label_proba': [0.4120317330733448, 0.5879682669266552],
#    'position': 'before'},
#   {'node': 'Music archaeology',
#    'similarity_rank': 0.0004045695808826089,
#    'label_proba': [0.5321013305141782, 0.4678986694858218],
#    'position': 'before'},
#   {'node': 'Sheet music',
#    'similarity_rank': 0.00040110246906944526,
#    'label_proba': [0.48781550831613496, 0.512184491683865],
#    'position': 'before'},
#   {'node': 'Set (music)',
#    'similarity_rank': 0.00040047360832208144,
#    'label_proba': [0.38829171866923945, 0.6117082813307607],
#    'position': 'before'},
#   {'node': 'Music therapy',
#    'similarity_rank': 0.00039600756190958877,
#    'label_proba': [0.5012494738223301, 0.4987505261776699],
#    'position': 'before'},
#   {'node': 'Books in the United States',
#    'similarity_rank': 0.0003944638131954504,
#    'label_proba': [0.5266703504533254, 0.47332964954667467],
#    'position': 'before'},
#   {'node': 'Audiobook',
#    'similarity_rank': 0.0003944638131954504,
#    'label_proba': [0.5266703504533254, 0.47332964954667467],
#    'position': 'before'}]}

# %% [markdown]
# # Optional: Format as DataFrame for Easy Viewing

# %%
recommendations = pd.DataFrame(rec.format_results()['predictions'])
print(recommendations.position.value_counts())
recommendations[['node', 'position']]
# Out:
# before    51
# after     48
# Name: position, dtype: int64
#                           node position
# 0     Dickinson classification   before
# 1                     Ian Bent    after
# 2      Transformational theory   before
# 3                  Tune-family    after
# 4     Society for Music Theory   before
# ..                         ...      ...
# 94                 Sheet music   before
# 95                 Set (music)   before
# 96               Music therapy   before
# 97  Books in the United States   before
# 98                   Audiobook   before
#
# [99 rows x 2 columns]
