# %% [markdown]
# This notebook shows how to use a `GraphCreator` instance in a recommendation pipeline to easily produce the top recommendations and display their predicted order (before/after)

# %%
# %load_ext autoreload
# %autoreload 1

import sys
sys.path.append('../utils/')

import pickle
import numpy as np
import pandas as pd

from GraphAPI import GraphCreator
from RecommenderPipeline import Recommender

from sklearn.preprocessing import normalize, StandardScaler, Normalizer, RobustScaler, MinMaxScaler, MaxAbsScaler


# %aimport GraphAPI
# %aimport RecommenderPipeline

# %% [markdown]
# # Load in Models

# %%
with open("../models/rf_classifier_v2_normalized.pkl", "rb") as model:
    rf_classifier = pickle.load(model)
    
with open("../models/xg_model_semisupervised_v2.pkl", "rb") as model:
    xg_classifier = pickle.load(model)

# %% [markdown]
# # Initialize `GraphCreator` Instance
#
# After initialization, pass as an argument to a new recommender instance

# %%
gc = GraphCreator("https://en.wikipedia.org/wiki/Melody")
print("Layer 1 nodes:", len(gc.graph.nodes))
rec = Recommender(gc)
# Out:
# Layer 1 nodes: 1363

# %% [markdown]
# # Fit the Recommender

# %%
rec.fit(scaler=Normalizer)

# %% [markdown]
# # Make Predictions
# Pass in your model to make predictions on the data

# %%
rec.predict(rf_classifier)
# rec.predict(xg_classifier)

# %% [markdown]
# # Format the Results
# Will return as a dictionary containing the entry node and the predictions of the top articles.

# %%
rec.format_results()
# Out:
# {'entry': 'Melody',
#  'predictions': [{'node': 'Pervading imitation',
#    'similarity_rank': 0.06332213161348413,
#    'label_proba': [0.5780918989403349, 0.421908101059665],
#    'position': 'after'},
#   {'node': 'Strain (music)',
#    'similarity_rank': 0.025056653290372367,
#    'label_proba': [0.4936511574421914, 0.5063488425578087],
#    'position': 'before'},
#   {'node': 'Tune-family',
#    'similarity_rank': 0.022391692265229635,
#    'label_proba': [0.5081196173538396, 0.49188038264616035],
#    'position': 'after'},
#   {'node': 'Contrast (music)',
#    'similarity_rank': 0.016110957296601683,
#    'label_proba': [0.5050508654188046, 0.4949491345811955],
#    'position': 'after'},
#   {'node': 'Centonization',
#    'similarity_rank': 0.015797737899771593,
#    'label_proba': [0.6165710234600875, 0.38342897653991254],
#    'position': 'after'},
#   {'node': 'Part (music)',
#    'similarity_rank': 0.015482890244493131,
#    'label_proba': [0.4613693854083318, 0.5386306145916683],
#    'position': 'before'},
#   {'node': 'Unified field',
#    'similarity_rank': 0.014273308104424766,
#    'label_proba': [0.49765847922200146, 0.5023415207779987],
#    'position': 'before'},
#   {'node': 'Contrapuntal motion',
#    'similarity_rank': 0.013755928502703716,
#    'label_proba': [0.46579736892007534, 0.5342026310799247],
#    'position': 'before'},
#   {'node': 'Sequence (music)',
#    'similarity_rank': 0.013149752218249175,
#    'label_proba': [0.4522914055053519, 0.5477085944946483],
#    'position': 'before'},
#   {'node': 'Melodic motion',
#    'similarity_rank': 0.011910618219014327,
#    'label_proba': [0.39743646482372663, 0.6025635351762734],
#    'position': 'before'},
#   {'node': 'Steps and skips',
#    'similarity_rank': 0.011899922101206025,
#    'label_proba': [0.45674247152752784, 0.5432575284724721],
#    'position': 'before'},
#   {'node': 'Qupai',
#    'similarity_rank': 0.01080035483132601,
#    'label_proba': [0.5678310929424721, 0.4321689070575278],
#    'position': 'after'},
#   {'node': 'Prolation canon',
#    'similarity_rank': 0.008857441635875016,
#    'label_proba': [0.5776542728399058, 0.42234572716009416],
#    'position': 'after'},
#   {'node': 'Level (music)',
#    'similarity_rank': 0.008426824404170957,
#    'label_proba': [0.5845709795099916, 0.41542902049000846],
#    'position': 'after'},
#   {'node': 'Hocket',
#    'similarity_rank': 0.007785352742903931,
#    'label_proba': [0.4850500906158026, 0.5149499093841974],
#    'position': 'before'},
#   {'node': 'Heterophony',
#    'similarity_rank': 0.00679436866160881,
#    'label_proba': [0.624028971860508, 0.37597102813949185],
#    'position': 'after'},
#   {'node': 'False relation',
#    'similarity_rank': 0.005851307995890054,
#    'label_proba': [0.5570685469782758, 0.44293145302172404],
#    'position': 'after'},
#   {'node': 'Figure (music)',
#    'similarity_rank': 0.005803232766514102,
#    'label_proba': [0.6036282180143434, 0.39637178198565665],
#    'position': 'after'},
#   {'node': 'Melodic pattern',
#    'similarity_rank': 0.005746033373629905,
#    'label_proba': [0.5536448103876084, 0.44635518961239157],
#    'position': 'after'},
#   {'node': 'René Challan',
#    'similarity_rank': 0.005579826348882107,
#    'label_proba': [0.6864187978668365, 0.3135812021331633],
#    'position': 'after'},
#   {'node': 'Subject (music)',
#    'similarity_rank': 0.005153183339245593,
#    'label_proba': [0.48647976404905413, 0.5135202359509458],
#    'position': 'before'},
#   {'node': 'Modal frame',
#    'similarity_rank': 0.004863303123242755,
#    'label_proba': [0.587282582578296, 0.4127174174217039],
#    'position': 'after'},
#   {'node': 'Irregular resolution',
#    'similarity_rank': 0.004784218045520962,
#    'label_proba': [0.5748357748600015, 0.4251642251399986],
#    'position': 'after'},
#   {'node': 'Parsons code',
#    'similarity_rank': 0.004778403539721183,
#    'label_proba': [0.5988746961749122, 0.4011253038250877],
#    'position': 'after'},
#   {'node': 'Hauptstimme',
#    'similarity_rank': 0.004755841378748067,
#    'label_proba': [0.5790808590587975, 0.4209191409412025],
#    'position': 'after'},
#   {'node': 'Steirische Harmonika',
#    'similarity_rank': 0.0047151858575460075,
#    'label_proba': [0.5853835121294374, 0.4146164878705626],
#    'position': 'after'},
#   {'node': 'Tension (music)',
#    'similarity_rank': 0.0046640286800726976,
#    'label_proba': [0.5154153681252929, 0.48458463187470713],
#    'position': 'after'},
#   {'node': 'Head (music)',
#    'similarity_rank': 0.00437917658624774,
#    'label_proba': [0.568977152158505, 0.4310228478414951],
#    'position': 'after'},
#   {'node': 'Phrase (music)',
#    'similarity_rank': 0.0042617572357092565,
#    'label_proba': [0.46591030758307306, 0.5340896924169269],
#    'position': 'before'},
#   {'node': 'Balungan',
#    'similarity_rank': 0.004168900917380054,
#    'label_proba': [0.6092285764881693, 0.39077142351183075],
#    'position': 'after'},
#   {'node': 'Counter-melody',
#    'similarity_rank': 0.003987328467487176,
#    'label_proba': [0.5168293555666871, 0.4831706444333127],
#    'position': 'after'},
#   {'node': 'Period (music)',
#    'similarity_rank': 0.0037568849214449293,
#    'label_proba': [0.5067610395644125, 0.49323896043558746],
#    'position': 'after'},
#   {'node': 'Close and open harmony',
#    'similarity_rank': 0.0035780612821140123,
#    'label_proba': [0.5623620422884826, 0.43763795771151726],
#    'position': 'after'},
#   {'node': 'Imitation (music)',
#    'similarity_rank': 0.0029688256801106826,
#    'label_proba': [0.5320085248029564, 0.46799147519704354],
#    'position': 'after'},
#   {'node': 'Wolfgang von Schweinitz',
#    'similarity_rank': 0.002623195834766287,
#    'label_proba': [0.621256949103817, 0.3787430508961831],
#    'position': 'after'},
#   {'node': 'Selle v. Gibb',
#    'similarity_rank': 0.002424240887095735,
#    'label_proba': [0.7006941519063687, 0.2993058480936311],
#    'position': 'after'},
#   {'node': 'Berber music',
#    'similarity_rank': 0.0022304243321715623,
#    'label_proba': [0.6381121781701148, 0.36188782182988516],
#    'position': 'after'},
#   {'node': 'Motif (music)',
#    'similarity_rank': 0.002139498365996736,
#    'label_proba': [0.5252254583941321, 0.47477454160586774],
#    'position': 'after'},
#   {'node': 'Exposition (music)',
#    'similarity_rank': 0.002135070202247307,
#    'label_proba': [0.49254743936455214, 0.5074525606354479],
#    'position': 'before'},
#   {'node': 'Texture (music)',
#    'similarity_rank': 0.002083798087695649,
#    'label_proba': [0.5341789162406697, 0.4658210837593302],
#    'position': 'after'},
#   {'node': 'Monody',
#    'similarity_rank': 0.0020662669579225856,
#    'label_proba': [0.5591623992091809, 0.4408376007908189],
#    'position': 'after'},
#   {'node': 'Piano Sonata No. 30 (Beethoven)',
#    'similarity_rank': 0.0020066693992492864,
#    'label_proba': [0.6628886428738612, 0.33711135712613866],
#    'position': 'after'},
#   {'node': 'Appoggiatura',
#    'similarity_rank': 0.0018764217465426273,
#    'label_proba': [0.5101420930400266, 0.4898579069599735],
#    'position': 'after'},
#   {'node': 'Monophony',
#    'similarity_rank': 0.001859282011992569,
#    'label_proba': [0.5369016258783963, 0.4630983741216035],
#    'position': 'after'},
#   {'node': 'Radif (music)',
#    'similarity_rank': 0.001679923046755986,
#    'label_proba': [0.5135882046463592, 0.48641179535364093],
#    'position': 'after'},
#   {'node': 'Metal Machine Music',
#    'similarity_rank': 0.0014958284290387748,
#    'label_proba': [0.6188193388627646, 0.38118066113723537],
#    'position': 'after'},
#   {'node': 'Quodlibet',
#    'similarity_rank': 0.0014672875454134,
#    'label_proba': [0.6386262464502139, 0.36137375354978607],
#    'position': 'after'},
#   {'node': 'Conclusion (music)',
#    'similarity_rank': 0.001459556015655386,
#    'label_proba': [0.509975870749734, 0.4900241292502659],
#    'position': 'after'},
#   {'node': 'Organum',
#    'similarity_rank': 0.0013978392693298845,
#    'label_proba': [0.6616152871685754, 0.33838471283142446],
#    'position': 'after'},
#   {'node': 'Accompaniment',
#    'similarity_rank': 0.0012833842841124177,
#    'label_proba': [0.42475247815403044, 0.5752475218459695],
#    'position': 'before'},
#   {'node': 'Symphony No. 35 (Mozart)',
#    'similarity_rank': 0.0012167694984335882,
#    'label_proba': [0.6678547743472975, 0.33214522565270244],
#    'position': 'after'},
#   {'node': 'Liaisons: Re-Imagining Sondheim from the Piano',
#    'similarity_rank': 0.0011298629628273703,
#    'label_proba': [0.7271530056562857, 0.2728469943437142],
#    'position': 'after'},
#   {'node': 'Traditional Japanese music',
#    'similarity_rank': 0.0010958448915715877,
#    'label_proba': [0.614795557374768, 0.38520444262523207],
#    'position': 'after'},
#   {'node': 'Folia',
#    'similarity_rank': 0.0009676147073840016,
#    'label_proba': [0.5401149951721452, 0.45988500482785466],
#    'position': 'after'},
#   {'node': 'Modulation (music)',
#    'similarity_rank': 0.0008654346855583141,
#    'label_proba': [0.5347297996798952, 0.46527020032010485],
#    'position': 'after'},
#   {'node': 'Canon (music)',
#    'similarity_rank': 0.0008635361681417796,
#    'label_proba': [0.5374374161172176, 0.46256258388278243],
#    'position': 'after'},
#   {'node': 'The Well-Tempered Clavier',
#    'similarity_rank': 0.00084164037042486,
#    'label_proba': [0.6560376963311927, 0.34396230366880703],
#    'position': 'after'},
#   {'node': 'Anton Reicha',
#    'similarity_rank': 0.0008343798621984527,
#    'label_proba': [0.5334635756596774, 0.46653642434032266],
#    'position': 'after'},
#   {'node': 'Mephisto Waltzes',
#    'similarity_rank': 0.0007575328273808946,
#    'label_proba': [0.6426801775738639, 0.3573198224261362],
#    'position': 'after'},
#   {'node': 'James Chance and the Contortions',
#    'similarity_rank': 0.0007413333996096929,
#    'label_proba': [0.5218715625662089, 0.4781284374337911],
#    'position': 'after'},
#   {'node': 'Polyphony',
#    'similarity_rank': 0.0007358802029316375,
#    'label_proba': [0.5866794805426937, 0.413320519457306],
#    'position': 'after'},
#   {'node': 'Arpeggio',
#    'similarity_rank': 0.0007355504924357465,
#    'label_proba': [0.49989217016622356, 0.5001078298337764],
#    'position': 'before'},
#   {'node': 'Atlantic slave trade',
#    'similarity_rank': 0.0006828908375556867,
#    'label_proba': [0.47062785607793345, 0.5293721439220664],
#    'position': 'before'},
#   {'node': 'The Pop Group',
#    'similarity_rank': 0.0006715029426226355,
#    'label_proba': [0.41326043772464166, 0.5867395622753584],
#    'position': 'before'},
#   {'node': 'Louisiana Creole people',
#    'similarity_rank': 0.0006303889611710113,
#    'label_proba': [0.4148736781427602, 0.5851263218572399],
#    'position': 'before'},
#   {'node': 'Afro-Cuban',
#    'similarity_rank': 0.0006271280561133561,
#    'label_proba': [0.44244030291928127, 0.5575596970807188],
#    'position': 'before'},
#   {'node': 'Anita Baker',
#    'similarity_rank': 0.0006236807295992377,
#    'label_proba': [0.4557409750612176, 0.5442590249387823],
#    'position': 'before'},
#   {'node': 'Cyril Davies',
#    'similarity_rank': 0.0005995184945371015,
#    'label_proba': [0.43481803047327466, 0.5651819695267253],
#    'position': 'before'},
#   {'node': 'Simon Frith',
#    'similarity_rank': 0.0005921960393717693,
#    'label_proba': [0.3868749752538191, 0.613125024746181],
#    'position': 'before'},
#   {'node': 'Books in Germany',
#    'similarity_rank': 0.0005914542701325004,
#    'label_proba': [0.5331587145638037, 0.4668412854361963],
#    'position': 'after'},
#   {'node': 'Books in the Netherlands',
#    'similarity_rank': 0.0005914542701325004,
#    'label_proba': [0.5331587145638037, 0.4668412854361963],
#    'position': 'after'},
#   {'node': 'Books in the United States',
#    'similarity_rank': 0.0005914542701325004,
#    'label_proba': [0.5331587145638037, 0.4668412854361963],
#    'position': 'after'},
#   {'node': 'Bookland',
#    'similarity_rank': 0.0005914542701325004,
#    'label_proba': [0.5331587145638037, 0.4668412854361963],
#    'position': 'after'},
#   {'node': 'Books in France',
#    'similarity_rank': 0.0005914542701325004,
#    'label_proba': [0.5331587145638037, 0.4668412854361963],
#    'position': 'after'},
#   {'node': 'Reading',
#    'similarity_rank': 0.0005914542701325004,
#    'label_proba': [0.5331587145638037, 0.4668412854361963],
#    'position': 'after'},
#   {'node': 'Bibliotherapy',
#    'similarity_rank': 0.0005914542701325004,
#    'label_proba': [0.5331587145638037, 0.4668412854361963],
#    'position': 'after'},
#   {'node': 'List of ISBN identifier groups',
#    'similarity_rank': 0.0005914542701325004,
#    'label_proba': [0.5331587145638037, 0.4668412854361963],
#    'position': 'after'},
#   {'node': 'Bibliothèque et Archives nationales du Québec',
#    'similarity_rank': 0.0005914542701325004,
#    'label_proba': [0.5331587145638037, 0.4668412854361963],
#    'position': 'after'},
#   {'node': 'ISO 639-6',
#    'similarity_rank': 0.0005914542701325004,
#    'label_proba': [0.5331587145638037, 0.4668412854361963],
#    'position': 'after'},
#   {'node': 'Tropical rock',
#    'similarity_rank': 0.0005884437234624743,
#    'label_proba': [0.4272981366060623, 0.5727018633939378],
#    'position': 'before'},
#   {'node': 'Rock Against Racism',
#    'similarity_rank': 0.0005884437234624743,
#    'label_proba': [0.4272981366060623, 0.5727018633939378],
#    'position': 'before'},
#   {'node': 'Sun Records',
#    'similarity_rank': 0.0005876292193610893,
#    'label_proba': [0.389018963947307, 0.610981036052693],
#    'position': 'before'},
#   {'node': 'Gerhard Kubik',
#    'similarity_rank': 0.0005857529371847894,
#    'label_proba': [0.4355633187922971, 0.564436681207703],
#    'position': 'before'},
#   {'node': 'Johnny Winter',
#    'similarity_rank': 0.0005840287338409355,
#    'label_proba': [0.4148736781427602, 0.5851263218572399],
#    'position': 'before'},
#   {'node': 'Willie Johnson (guitarist)',
#    'similarity_rank': 0.0005791151277225953,
#    'label_proba': [0.442851961850654, 0.557148038149346],
#    'position': 'before'},
#   {'node': 'Fila Brazillia',
#    'similarity_rank': 0.0005723835523734353,
#    'label_proba': [0.5331587145638037, 0.4668412854361963],
#    'position': 'after'},
#   {'node': 'Afro Blue',
#    'similarity_rank': 0.0005723835523734353,
#    'label_proba': [0.5331587145638037, 0.4668412854361963],
#    'position': 'after'},
#   {'node': 'Cory Henry',
#    'similarity_rank': 0.0005723835523734353,
#    'label_proba': [0.5331587145638037, 0.4668412854361963],
#    'position': 'after'},
#   {'node': 'Max Kaminsky (musician)',
#    'similarity_rank': 0.0005723835523734353,
#    'label_proba': [0.5331587145638037, 0.4668412854361963],
#    'position': 'after'},
#   {'node': 'Black Arts Movement',
#    'similarity_rank': 0.0005723835523734353,
#    'label_proba': [0.5331587145638037, 0.4668412854361963],
#    'position': 'after'},
#   {'node': 'Spy vs Spy (album)',
#    'similarity_rank': 0.0005723835523734353,
#    'label_proba': [0.5331587145638037, 0.4668412854361963],
#    'position': 'after'},
#   {'node': 'William Krell',
#    'similarity_rank': 0.0005723835523734353,
#    'label_proba': [0.5331587145638037, 0.4668412854361963],
#    'position': 'after'},
#   {'node': 'Race record',
#    'similarity_rank': 0.000561877811217166,
#    'label_proba': [0.451869594029673, 0.5481304059703269],
#    'position': 'before'},
#   {'node': 'Paul Butterfield',
#    'similarity_rank': 0.000561877811217166,
#    'label_proba': [0.451869594029673, 0.5481304059703269],
#    'position': 'before'},
#   {'node': 'Robert Palmer (writer)',
#    'similarity_rank': 0.0005599257487915028,
#    'label_proba': [0.37750189233520026, 0.6224981076647998],
#    'position': 'before'},
#   {'node': 'Rock music and the fall of communism',
#    'similarity_rank': 0.0005598756816143155,
#    'label_proba': [0.442851961850654, 0.557148038149346],
#    'position': 'before'},
#   {'node': 'Pop Chronicles',
#    'similarity_rank': 0.000557607089474806,
#    'label_proba': [0.4412968046117072, 0.5587031953882929],
#    'position': 'before'},
#   {'node': 'Émile Prudent',
#    'similarity_rank': 0.0005561210686044189,
#    'label_proba': [0.4503969559287653, 0.5496030440712348],
#    'position': 'before'},
#   {'node': 'Philipp Otto Runge',
#    'similarity_rank': 0.0005551351044151564,
#    'label_proba': [0.4675330621762766, 0.5324669378237235],
#    'position': 'before'}]}

# %% [markdown]
# # Optional: Format as DataFrame for Easy Viewing

# %%
recommendations = pd.DataFrame(rec.format_results(decision_threshold=0.53)['predictions'])
print(recommendations.position.value_counts())
recommendations
# Out:
# after     56
# before    43
# Name: position, dtype: int64
#                                     node  similarity_rank  \
# 0                    Pervading imitation         0.063322
# 1                         Strain (music)         0.025057
# 2                            Tune-family         0.022392
# 3                       Contrast (music)         0.016111
# 4                          Centonization         0.015798
# ..                                   ...              ...
# 94                Robert Palmer (writer)         0.000560
# 95  Rock music and the fall of communism         0.000560
# 96                        Pop Chronicles         0.000558
# 97                         Émile Prudent         0.000556
# 98                    Philipp Otto Runge         0.000555
#
#                                   label_proba position
# 0     [0.5780918989403349, 0.421908101059665]    after
# 1    [0.4936511574421914, 0.5063488425578087]   before
# 2   [0.5081196173538396, 0.49188038264616035]   before
# 3    [0.5050508654188046, 0.4949491345811955]   before
# 4   [0.6165710234600875, 0.38342897653991254]    after
# ..                                        ...      ...
# 94  [0.37750189233520026, 0.6224981076647998]   before
# 95     [0.442851961850654, 0.557148038149346]   before
# 96   [0.4412968046117072, 0.5587031953882929]   before
# 97   [0.4503969559287653, 0.5496030440712348]   before
# 98   [0.4675330621762766, 0.5324669378237235]   before
#
# [99 rows x 4 columns]
