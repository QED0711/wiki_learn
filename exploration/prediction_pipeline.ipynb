# %% [markdown]
# This notebook shows how to use a `GraphCreator` instance in a recommendation pipeline to easily produce the top recommendations and display their predicted order (before/after)

# %%
# %load_ext autoreload
# %autoreload 1

import sys
sys.path.append('../utils/')

import pickle
import numpy as np
import pandas as pd

from GraphAPI import GraphCreator
from RecommenderPipeline import Recommender

# %aimport GraphAPI
# %aimport RecommenderPipeline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Load in Models

# %%
with open("../models/rf_classifier_v1.pkl", "rb") as model:
    rf_classifier = pickle.load(model)
    
with open("../models/xg_model_semisupervised_v2.pkl", "rb") as model:
    xg_classifier = pickle.load(model)

# %% [markdown]
# # Initialize `GraphCreator` Instance
#
# After initialization, pass as an argument to a new recommender instance

# %%
gc = GraphCreator("Random forest")

rec = Recommender(gc)

# %% [markdown]
# # Fit the Recommender

# %%
rec.fit()

# %% [markdown]
# # Make Predictions
# Pass in your model to make predictions on the data

# %%
# rec.predict(rf_classifier)
rec.predict(xg_classifier)

# %% [markdown]
# # Format the Results
# Will return as a dictionary containing the entry node and the predictions of the top articles.

# %%
rec.format_results()
# Out:
# {'entry': 'Random forest',
#  'predictions': [{'node': 'Gradient boosting',
#    'similarity_rank': 0.4630790046098889,
#    'label_proba': [0.7603876, 0.23961239],
#    'position': 'after'},
#   {'node': 'Bootstrap aggregating',
#    'similarity_rank': 0.3634512542627948,
#    'label_proba': [0.7603876, 0.23961239],
#    'position': 'after'},
#   {'node': 'Random subspace method',
#    'similarity_rank': 0.35131036668631516,
#    'label_proba': [0.6958413, 0.30415866],
#    'position': 'after'},
#   {'node': 'Boosting (machine learning)',
#    'similarity_rank': 0.34222910690733754,
#    'label_proba': [0.7603876, 0.23961239],
#    'position': 'after'},
#   {'node': 'Decision tree learning',
#    'similarity_rank': 0.33156399011065724,
#    'label_proba': [0.7114601, 0.2885399],
#    'position': 'after'},
#   {'node': 'Out-of-bag error',
#    'similarity_rank': 0.26015245491017647,
#    'label_proba': [0.7603876, 0.23961239],
#    'position': 'after'},
#   {'node': 'Ensemble learning',
#    'similarity_rank': 0.23918203280280198,
#    'label_proba': [0.7603876, 0.23961239],
#    'position': 'after'},
#   {'node': 'Statistical classification',
#    'similarity_rank': 0.206133283585981,
#    'label_proba': [0.38932252, 0.6106775],
#    'position': 'before'},
#   {'node': 'Logic learning machine',
#    'similarity_rank': 0.17729043531294367,
#    'label_proba': [0.7603876, 0.23961239],
#    'position': 'after'},
#   {'node': 'Occam learning',
#    'similarity_rank': 0.17223890161342828,
#    'label_proba': [0.7603876, 0.23961239],
#    'position': 'after'},
#   {'node': 'AdaBoost',
#    'similarity_rank': 0.17068496391697918,
#    'label_proba': [0.7603876, 0.23961239],
#    'position': 'after'},
#   {'node': 'Relevance vector machine',
#    'similarity_rank': 0.16839561840171477,
#    'label_proba': [0.7603876, 0.23961239],
#    'position': 'after'},
#   {'node': 'Feature engineering',
#    'similarity_rank': 0.1678864484915423,
#    'label_proba': [0.7114601, 0.2885399],
#    'position': 'after'},
#   {'node': 'Empirical risk minimization',
#    'similarity_rank': 0.16394969272952792,
#    'label_proba': [0.7603876, 0.23961239],
#    'position': 'after'},
#   {'node': 'Automated machine learning',
#    'similarity_rank': 0.16273830301269906,
#    'label_proba': [0.7114601, 0.2885399],
#    'position': 'after'},
#   {'node': 'Bias–variance tradeoff',
#    'similarity_rank': 0.16177122533844843,
#    'label_proba': [0.7114601, 0.2885399],
#    'position': 'after'},
#   {'node': 'Feature learning',
#    'similarity_rank': 0.16122910284137326,
#    'label_proba': [0.7603876, 0.23961239],
#    'position': 'after'},
#   {'node': 'Semi-supervised learning',
#    'similarity_rank': 0.15970344211427936,
#    'label_proba': [0.7114601, 0.2885399],
#    'position': 'after'},
#   {'node': 'Anomaly detection',
#    'similarity_rank': 0.15884051703793073,
#    'label_proba': [0.7114601, 0.2885399],
#    'position': 'after'},
#   {'node': 'Multilayer perceptron',
#    'similarity_rank': 0.15723153321298516,
#    'label_proba': [0.7114601, 0.2885399],
#    'position': 'after'},
#   {'node': 'Statistical learning theory',
#    'similarity_rank': 0.15487937576705132,
#    'label_proba': [0.7114601, 0.2885399],
#    'position': 'after'},
#   {'node': 'K-nearest neighbors algorithm',
#    'similarity_rank': 0.15407572352547386,
#    'label_proba': [0.7114601, 0.2885399],
#    'position': 'after'},
#   {'node': 'Conditional random field',
#    'similarity_rank': 0.15342398709529725,
#    'label_proba': [0.7114601, 0.2885399],
#    'position': 'after'},
#   {'node': 'Overfitting',
#    'similarity_rank': 0.15200620450229177,
#    'label_proba': [0.63997424, 0.3600258],
#    'position': 'after'},
#   {'node': 'Learning to rank',
#    'similarity_rank': 0.15179345059882848,
#    'label_proba': [0.7114601, 0.2885399],
#    'position': 'after'},
#   {'node': 'Support-vector machine',
#    'similarity_rank': 0.15077246258969249,
#    'label_proba': [0.7114601, 0.2885399],
#    'position': 'after'},
#   {'node': 'Grammar induction',
#    'similarity_rank': 0.15003098384128247,
#    'label_proba': [0.7114601, 0.2885399],
#    'position': 'after'},
#   {'node': 'Computational learning theory',
#    'similarity_rank': 0.1488913237830621,
#    'label_proba': [0.7114601, 0.2885399],
#    'position': 'after'},
#   {'node': 'List of datasets for machine-learning research',
#    'similarity_rank': 0.145993655465627,
#    'label_proba': [0.7114601, 0.2885399],
#    'position': 'after'},
#   {'node': 'Perceptron',
#    'similarity_rank': 0.14364422056907847,
#    'label_proba': [0.7114601, 0.2885399],
#    'position': 'after'},
#   {'node': 'Naive Bayes classifier',
#    'similarity_rank': 0.1426976295718728,
#    'label_proba': [0.7114601, 0.2885399],
#    'position': 'after'},
#   {'node': 'Dimensionality reduction',
#    'similarity_rank': 0.14121801560955674,
#    'label_proba': [0.7114601, 0.2885399],
#    'position': 'after'},
#   {'node': 'Kernel method',
#    'similarity_rank': 0.13859894050002144,
#    'label_proba': [0.7603876, 0.23961239],
#    'position': 'after'},
#   {'node': 'Artificial neural network',
#    'similarity_rank': 0.13666578088308293,
#    'label_proba': [0.33589572, 0.6641043],
#    'position': 'before'},
#   {'node': 'Convolutional neural network',
#    'similarity_rank': 0.1229233874493019,
#    'label_proba': [0.7114601, 0.2885399],
#    'position': 'after'},
#   {'node': 'Unsupervised learning',
#    'similarity_rank': 0.1214191468981892,
#    'label_proba': [0.46930754, 0.53069246],
#    'position': 'before'},
#   {'node': 'Leo Breiman',
#    'similarity_rank': 0.11815277827039931,
#    'label_proba': [0.6958413, 0.30415866],
#    'position': 'after'},
#   {'node': 'Tin Kam Ho',
#    'similarity_rank': 0.11750917669240367,
#    'label_proba': [0.6958413, 0.30415866],
#    'position': 'after'},
#   {'node': 'Adele Cutler',
#    'similarity_rank': 0.11749587788822881,
#    'label_proba': [0.6958413, 0.30415866],
#    'position': 'after'},
#   {'node': 'Supervised learning',
#    'similarity_rank': 0.11730863292302442,
#    'label_proba': [0.46930754, 0.53069246],
#    'position': 'before'},
#   {'node': 'Donald Geman',
#    'similarity_rank': 0.11615846807572557,
#    'label_proba': [0.6958413, 0.30415866],
#    'position': 'after'},
#   {'node': 'Machine Learning (journal)',
#    'similarity_rank': 0.11536548969858318,
#    'label_proba': [0.7114601, 0.2885399],
#    'position': 'after'},
#   {'node': 'Journal of Machine Learning Research',
#    'similarity_rank': 0.10704229596025512,
#    'label_proba': [0.7114601, 0.2885399],
#    'position': 'after'},
#   {'node': 'Decision tree',
#    'similarity_rank': 0.10498834455570855,
#    'label_proba': [0.63997424, 0.3600258],
#    'position': 'after'},
#   {'node': 'Multiple instance learning',
#    'similarity_rank': 0.10462962944058346,
#    'label_proba': [0.7603876, 0.23961239],
#    'position': 'after'},
#   {'node': 'Labeled data',
#    'similarity_rank': 0.10387255618595853,
#    'label_proba': [0.7603876, 0.23961239],
#    'position': 'after'},
#   {'node': 'Model-free (reinforcement learning)',
#    'similarity_rank': 0.10353322954416287,
#    'label_proba': [0.7603876, 0.23961239],
#    'position': 'after'},
#   {'node': 'Error tolerance (PAC learning)',
#    'similarity_rank': 0.10315724411487179,
#    'label_proba': [0.7603876, 0.23961239],
#    'position': 'after'},
#   {'node': 'Logistic model tree',
#    'similarity_rank': 0.10308732803410826,
#    'label_proba': [0.7603876, 0.23961239],
#    'position': 'after'},
#   {'node': 'Feature scaling',
#    'similarity_rank': 0.10275013890707729,
#    'label_proba': [0.7603876, 0.23961239],
#    'position': 'after'},
#   {'node': 'Sample complexity',
#    'similarity_rank': 0.10257131705309558,
#    'label_proba': [0.7603876, 0.23961239],
#    'position': 'after'},
#   {'node': 'Active learning (machine learning)',
#    'similarity_rank': 0.10239154523565304,
#    'label_proba': [0.7603876, 0.23961239],
#    'position': 'after'},
#   {'node': 'Action model learning',
#    'similarity_rank': 0.1018587416742084,
#    'label_proba': [0.7603876, 0.23961239],
#    'position': 'after'},
#   {'node': 'Learning rate',
#    'similarity_rank': 0.10085434439333837,
#    'label_proba': [0.7603876, 0.23961239],
#    'position': 'after'},
#   {'node': 'Vanishing gradient problem',
#    'similarity_rank': 0.10038891305640359,
#    'label_proba': [0.7603876, 0.23961239],
#    'position': 'after'},
#   {'node': 'Sparse dictionary learning',
#    'similarity_rank': 0.09852566900770982,
#    'label_proba': [0.7603876, 0.23961239],
#    'position': 'after'},
#   {'node': 'Caffe (software)',
#    'similarity_rank': 0.09576769381673711,
#    'label_proba': [0.7603876, 0.23961239],
#    'position': 'after'},
#   {'node': 'Linear discriminant analysis',
#    'similarity_rank': 0.09389889525122712,
#    'label_proba': [0.63997424, 0.3600258],
#    'position': 'after'},
#   {'node': 'Deeplearning4j',
#    'similarity_rank': 0.09089305221209106,
#    'label_proba': [0.7603876, 0.23961239],
#    'position': 'after'},
#   {'node': 'Word2vec',
#    'similarity_rank': 0.09041097663483906,
#    'label_proba': [0.7603876, 0.23961239],
#    'position': 'after'},
#   {'node': 'Training, validation, and test sets',
#    'similarity_rank': 0.0882373625724247,
#    'label_proba': [0.6958413, 0.30415866],
#    'position': 'after'},
#   {'node': 'Feature (machine learning)',
#    'similarity_rank': 0.08667177564467722,
#    'label_proba': [0.6958413, 0.30415866],
#    'position': 'after'},
#   {'node': 'Generalization error',
#    'similarity_rank': 0.08102068521057229,
#    'label_proba': [0.6958413, 0.30415866],
#    'position': 'after'},
#   {'node': 'Machine learning in bioinformatics',
#    'similarity_rank': 0.08053274100172367,
#    'label_proba': [0.6958413, 0.30415866],
#    'position': 'after'},
#   {'node': 'Timeline of machine learning',
#    'similarity_rank': 0.07994216500449623,
#    'label_proba': [0.6958413, 0.30415866],
#    'position': 'after'},
#   {'node': 'Jackknife variance estimates for random forest',
#    'similarity_rank': 0.07876877078440805,
#    'label_proba': [0.6958413, 0.30415866],
#    'position': 'after'},
#   {'node': 'Learning curve (machine learning)',
#    'similarity_rank': 0.07850257407999758,
#    'label_proba': [0.7603876, 0.23961239],
#    'position': 'after'},
#   {'node': 'Multinomial logistic regression',
#    'similarity_rank': 0.07748590316277978,
#    'label_proba': [0.6958413, 0.30415866],
#    'position': 'after'},
#   {'node': 'Outline of machine learning',
#    'similarity_rank': 0.07614593467338937,
#    'label_proba': [0.63997424, 0.3600258],
#    'position': 'after'},
#   {'node': 'Discriminative model',
#    'similarity_rank': 0.07594061198580987,
#    'label_proba': [0.6958413, 0.30415866],
#    'position': 'after'},
#   {'node': 'Generative model',
#    'similarity_rank': 0.07450503132913187,
#    'label_proba': [0.6958413, 0.30415866],
#    'position': 'after'},
#   {'node': 'Mean shift',
#    'similarity_rank': 0.07282158296807098,
#    'label_proba': [0.7603876, 0.23961239],
#    'position': 'after'},
#   {'node': 'State–action–reward–state–action',
#    'similarity_rank': 0.07209349071997752,
#    'label_proba': [0.7603876, 0.23961239],
#    'position': 'after'},
#   {'node': 'CURE algorithm',
#    'similarity_rank': 0.07164076125634723,
#    'label_proba': [0.7603876, 0.23961239],
#    'position': 'after'},
#   {'node': 'Local outlier factor',
#    'similarity_rank': 0.07073714647489143,
#    'label_proba': [0.7603876, 0.23961239],
#    'position': 'after'},
#   {'node': 'U-Net',
#    'similarity_rank': 0.07036356407744253,
#    'label_proba': [0.7603876, 0.23961239],
#    'position': 'after'},
#   {'node': 'BIRCH',
#    'similarity_rank': 0.06875050707079212,
#    'label_proba': [0.7603876, 0.23961239],
#    'position': 'after'},
#   {'node': 'Regression analysis',
#    'similarity_rank': 0.06866006354832545,
#    'label_proba': [0.33589572, 0.6641043],
#    'position': 'before'},
#   {'node': 'OPTICS algorithm',
#    'similarity_rank': 0.0686515840032709,
#    'label_proba': [0.7603876, 0.23961239],
#    'position': 'after'},
#   {'node': 'Temporal difference learning',
#    'similarity_rank': 0.06800363163902468,
#    'label_proba': [0.7114601, 0.2885399],
#    'position': 'after'},
#   {'node': 'Pattern recognition',
#    'similarity_rank': 0.06764925929695556,
#    'label_proba': [0.33589572, 0.6641043],
#    'position': 'before'},
#   {'node': 'T-distributed stochastic neighbor embedding',
#    'similarity_rank': 0.06731734539877215,
#    'label_proba': [0.7603876, 0.23961239],
#    'position': 'after'},
#   {'node': 'Q-learning',
#    'similarity_rank': 0.0660831588407046,
#    'label_proba': [0.7603876, 0.23961239],
#    'position': 'after'},
#   {'node': 'Randomized algorithm',
#    'similarity_rank': 0.06591550502399988,
#    'label_proba': [0.38932252, 0.6106775],
#    'position': 'before'},
#   {'node': 'DBSCAN',
#    'similarity_rank': 0.06515789495364337,
#    'label_proba': [0.7603876, 0.23961239],
#    'position': 'after'},
#   {'node': 'Probably approximately correct learning',
#    'similarity_rank': 0.06400461775243814,
#    'label_proba': [0.7603876, 0.23961239],
#    'position': 'after'},
#   {'node': 'Cross-validation (statistics)',
#    'similarity_rank': 0.0636972976767528,
#    'label_proba': [0.33589572, 0.6641043],
#    'position': 'before'},
#   {'node': 'International Conference on Machine Learning',
#    'similarity_rank': 0.06336817453795383,
#    'label_proba': [0.7603876, 0.23961239],
#    'position': 'after'},
#   {'node': 'DeepDream',
#    'similarity_rank': 0.063290613179358,
#    'label_proba': [0.7603876, 0.23961239],
#    'position': 'after'},
#   {'node': 'Mode (statistics)',
#    'similarity_rank': 0.06181692143976099,
#    'label_proba': [0.38932252, 0.6106775],
#    'position': 'before'},
#   {'node': 'Restricted Boltzmann machine',
#    'similarity_rank': 0.06166673613906851,
#    'label_proba': [0.7114601, 0.2885399],
#    'position': 'after'},
#   {'node': 'Vapnik–Chervonenkis theory',
#    'similarity_rank': 0.06151226874732027,
#    'label_proba': [0.7603876, 0.23961239],
#    'position': 'after'},
#   {'node': 'Autoencoder',
#    'similarity_rank': 0.06120673947566859,
#    'label_proba': [0.7603876, 0.23961239],
#    'position': 'after'},
#   {'node': 'Association rule learning',
#    'similarity_rank': 0.06085892483981233,
#    'label_proba': [0.7114601, 0.2885399],
#    'position': 'after'},
#   {'node': 'Structured prediction',
#    'similarity_rank': 0.060778758986371174,
#    'label_proba': [0.7603876, 0.23961239],
#    'position': 'after'},
#   {'node': 'Online machine learning',
#    'similarity_rank': 0.060085246544199084,
#    'label_proba': [0.7603876, 0.23961239],
#    'position': 'after'},
#   {'node': 'Generative adversarial network',
#    'similarity_rank': 0.059298426583212764,
#    'label_proba': [0.7603876, 0.23961239],
#    'position': 'after'},
#   {'node': 'Minitab',
#    'similarity_rank': 0.05506620008666832,
#    'label_proba': [0.6020656, 0.39793438],
#    'position': 'after'},
#   {'node': 'Long short-term memory',
#    'similarity_rank': 0.05489836439437327,
#    'label_proba': [0.7114601, 0.2885399],
#    'position': 'after'}]}

# %% [markdown]
# # Optional: Format as DataFrame for Easy Viewing

# %%
pd.DataFrame(rec.format_results()['predictions'])
# Out:
#                               node  similarity_rank              label_proba  \
# 0                Gradient boosting         0.463079  [0.7603876, 0.23961239]
# 1            Bootstrap aggregating         0.363451  [0.7603876, 0.23961239]
# 2           Random subspace method         0.351310  [0.6958413, 0.30415866]
# 3      Boosting (machine learning)         0.342229  [0.7603876, 0.23961239]
# 4           Decision tree learning         0.331564   [0.7114601, 0.2885399]
# ..                             ...              ...                      ...
# 94           Structured prediction         0.060779  [0.7603876, 0.23961239]
# 95         Online machine learning         0.060085  [0.7603876, 0.23961239]
# 96  Generative adversarial network         0.059298  [0.7603876, 0.23961239]
# 97                         Minitab         0.055066  [0.6020656, 0.39793438]
# 98          Long short-term memory         0.054898   [0.7114601, 0.2885399]
#
#    position
# 0     after
# 1     after
# 2     after
# 3     after
# 4     after
# ..      ...
# 94    after
# 95    after
# 96    after
# 97    after
# 98    after
#
# [99 rows x 4 columns]
