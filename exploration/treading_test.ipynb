# %%
import threading
from queue import Queue
import requests
import bs4
import time

# %%
print_lock = threading.Lock()

def get_url(current_url):

    with print_lock:
        print("\nStarting thread {}".format(threading.current_thread().name))
    res = requests.get(current_url)
    res.raise_for_status()

    current_page = bs4.BeautifulSoup(res.text,"html.parser")
    current_title = current_page.select('title')[0].getText()

    with print_lock:
        print("{}\n".format(threading.current_thread().name))
        print("{}\n".format(current_url))
        print("{}\n".format(current_title))
        print("\nFinished fetching : {}".format(current_url))

def process_queue():
    while True:
        current_url = url_queue.get()
        get_url(current_url)
        url_queue.task_done()

url_queue = Queue()

url_list = ["https://www.google.com"]*100

for i in range(5):
    t = threading.Thread(target=process_queue)
    t.daemon = True
    t.start()

start = time.time()

for current_url in url_list:
    url_queue.put(current_url)

url_queue.join()

print(threading.enumerate())

print("Execution time = {0:.5f}".format(time.time() - start))
# Out:
# Starting thread Thread-9
#
# Starting thread Thread-13
#
# Starting thread Thread-12
#
# Starting thread Thread-11
#
# Starting thread Thread-10
# Thread-13
#
# https://www.google.com
#
# Google
#
#
# Finished fetching : https://www.google.com
#
# Starting thread Thread-13
# Thread-9
#
# https://www.google.com
#
# Google
#
#
# Finished fetching : https://www.google.com
# Thread-11
#
# https://www.google.com
#
# Google
#
#
# Finished fetching : https://www.google.com
# Thread-12
#
# https://www.google.com
#
# Google
#
#
# Finished fetching : https://www.google.com
#
# Starting thread Thread-12
#
# Starting thread Thread-11
#
# Starting thread Thread-9
# Thread-10
#
# https://www.google.com
#
# Google
#
#
# Finished fetching : https://www.google.com
#
# Starting thread Thread-10
# Thread-13
#
# https://www.google.com
#
# Google
#
#
# Finished fetching : https://www.google.com
#
# Starting thread Thread-13
# Thread-11
#
# https://www.google.com
#
# Google
#
#
# Finished fetching : https://www.google.com
# Thread-9
#
# https://www.google.com
#
# Google
#
#
# Finished fetching : https://www.google.com
#
# Starting thread Thread-11
#
# Starting thread Thread-9
# Thread-12
#
# https://www.google.com
#
# Google
#
#
# Finished fetching : https://www.google.com
#
# Starting thread Thread-12
# Thread-10
#
# https://www.google.com
#
# Google
#
#
# Finished fetching : https://www.google.com
#
# Starting thread Thread-10
# Thread-13
#
# https://www.google.com
#
# Google
#
#
# Finished fetching : https://www.google.com
#
# Starting thread Thread-13
# Thread-11
#
# https://www.google.com
#
# Google
#
#
# Finished fetching : https://www.google.com
#
# Starting thread Thread-11
# Thread-9
#
# https://www.google.com
#
# Google
#
#
# Finished fetching : https://www.google.com
#
# Starting thread Thread-9
# Thread-12
#
# https://www.google.com
#
# Google
#
#
# Finished fetching : https://www.google.com
#
# Starting thread Thread-12
# Thread-10
#
# https://www.google.com
#
# Google
#
#
# Finished fetching : https://www.google.com
#
# Starting thread Thread-10
# Thread-13
#
# https://www.google.com
#
# Google
#
#
# Finished fetching : https://www.google.com
#
# Starting thread Thread-13
# Thread-9
#
# https://www.google.com
#
# Google
#
#
# Finished fetching : https://www.google.com
#
# Starting thread Thread-9
# Thread-11
#
# https://www.google.com
#
# Google
#
#
# Finished fetching : https://www.google.com
# Thread-10
#
# https://www.google.com
#
# Google
#
#
# Finished fetching : https://www.google.com
#
# Starting thread Thread-11
#
# Starting thread Thread-10
# Thread-12
#
# https://www.google.com
#
# Google
#
#
# Finished fetching : https://www.google.com
#
# Starting thread Thread-12
# Thread-13
#
# https://www.google.com
#
# Google
#
#
# Finished fetching : https://www.google.com
#
# Starting thread Thread-13
# Thread-9
#
# https://www.google.com
#
# Google
#
#
# Finished fetching : https://www.google.com
#
# Starting thread Thread-9
# Thread-12
#
# https://www.google.com
#
# Google
#
#
# Finished fetching : https://www.google.com
#
# Starting thread Thread-12
# Thread-11
#
# https://www.google.com
#
# Google
#
#
# Finished fetching : https://www.google.com
#
# Starting thread Thread-11
# Thread-10
#
# https://www.google.com
#
# Google
#
#
# Finished fetching : https://www.google.com
# Thread-13
#
# https://www.google.com
#
# Google
#
#
# Finished fetching : https://www.google.com
#
# Starting thread Thread-10
#
# Starting thread Thread-13
# Thread-9
#
# https://www.google.com
#
# Google
#
#
# Finished fetching : https://www.google.com
#
# Starting thread Thread-9
# Thread-12
#
# https://www.google.com
#
# Google
#
#
# Finished fetching : https://www.google.com
#
# Starting thread Thread-12
# Thread-13
#
# https://www.google.com
#
# Google
#
#
# Finished fetching : https://www.google.com
#
# Starting thread Thread-13
# Thread-11
#
# https://www.google.com
#
# Google
#
#
# Finished fetching : https://www.google.com
# Thread-10
#
# https://www.google.com
#
# Google
#
#
# Finished fetching : https://www.google.com
#
# Starting thread Thread-11
#
# Starting thread Thread-10
# Thread-9
#
# https://www.google.com
#
# Google
#
#
# Finished fetching : https://www.google.com
#
# Starting thread Thread-9
# Thread-13
#
# https://www.google.com
#
# Google
#
#
# Finished fetching : https://www.google.com
#
# Starting thread Thread-13
# Thread-12
#
# https://www.google.com
#
# Google
#
#
# Finished fetching : https://www.google.com
#
# Starting thread Thread-12
# Thread-10
#
# https://www.google.com
#
# Google
#
#
# Finished fetching : https://www.google.com
#
# Starting thread Thread-10
# Thread-11
#
# https://www.google.com
#
# Google
#
#
# Finished fetching : https://www.google.com
#
# Starting thread Thread-11
# Thread-9
#
# https://www.google.com
#
# Google
#
#
# Finished fetching : https://www.google.com
#
# Starting thread Thread-9
# Thread-13
#
# https://www.google.com
#
# Google
#
#
# Finished fetching : https://www.google.com
#
# Starting thread Thread-13
# Thread-12
#
# https://www.google.com
#
# Google
#
#
# Finished fetching : https://www.google.com
#
# Starting thread Thread-12
# Thread-10
#
# https://www.google.com
#
# Google
#
#
# Finished fetching : https://www.google.com
#
# Starting thread Thread-10
# Thread-11
#
# https://www.google.com
#
# Google
#
#
# Finished fetching : https://www.google.com
#
# Starting thread Thread-11
# Thread-13
#
# https://www.google.com
#
# Google
#
#
# Finished fetching : https://www.google.com
#
# Starting thread Thread-13
# Thread-12
#
# https://www.google.com
#
# Google
#
#
# Finished fetching : https://www.google.com
#
# Starting thread Thread-12
# Thread-10
#
# https://www.google.com
#
# Google
#
#
# Finished fetching : https://www.google.com
#
# Starting thread Thread-10
# Thread-11
#
# https://www.google.com
#
# Google
#
#
# Finished fetching : https://www.google.com
#
# Starting thread Thread-11
# Thread-9
#
# https://www.google.com
#
# Google
#
#
# Finished fetching : https://www.google.com
#
# Starting thread Thread-9
# Thread-13
#
# https://www.google.com
#
# Google
#
#
# Finished fetching : https://www.google.com
#
# Starting thread Thread-13
# Thread-12
#
# https://www.google.com
#
# Google
#
#
# Finished fetching : https://www.google.com
#
# Starting thread Thread-12
# Thread-10
#
# https://www.google.com
#
# Google
#
#
# Finished fetching : https://www.google.com
#
# Starting thread Thread-10
# Thread-11
#
# https://www.google.com
#
# Google
#
#
# Finished fetching : https://www.google.com
#
# Starting thread Thread-11
# Thread-9
#
# https://www.google.com
#
# Google
#
#
# Finished fetching : https://www.google.com
# Thread-13
#
# https://www.google.com
#
# Google
#
#
# Finished fetching : https://www.google.com
#
# Starting thread Thread-9
#
# Starting thread Thread-13
# Thread-12
#
# https://www.google.com
#
# Google
#
#
# Finished fetching : https://www.google.com
# Thread-11
#
# https://www.google.com
#
# Google
#
#
# Finished fetching : https://www.google.com
#
# Starting thread Thread-12
#
# Starting thread Thread-11
# Thread-10
#
# https://www.google.com
#
# Google
#
#
# Finished fetching : https://www.google.com
#
# Starting thread Thread-10
# Thread-13
#
# https://www.google.com
#
# Google
#
#
# Finished fetching : https://www.google.com
#
# Starting thread Thread-13
# Thread-9
#
# https://www.google.com
#
# Google
#
#
# Finished fetching : https://www.google.com
#
# Starting thread Thread-9
# Thread-10
#
# https://www.google.com
#
# Google
#
#
# Finished fetching : https://www.google.com
#
# Starting thread Thread-10
# Thread-11
#
# https://www.google.com
#
# Google
#
#
# Finished fetching : https://www.google.com
# Thread-12
#
# https://www.google.com
#
# Google
#
#
# Finished fetching : https://www.google.com
#
# Starting thread Thread-11
#
# Starting thread Thread-12
# Thread-13
#
# https://www.google.com
#
# Google
#
#
# Finished fetching : https://www.google.com
#
# Starting thread Thread-13
# Thread-9
#
# https://www.google.com
#
# Google
#
#
# Finished fetching : https://www.google.com
#
# Starting thread Thread-9
# Thread-10
#
# https://www.google.com
#
# Google
#
#
# Finished fetching : https://www.google.com
#
# Starting thread Thread-10
# Thread-12
#
# https://www.google.com
#
# Google
#
#
# Finished fetching : https://www.google.com
#
# Starting thread Thread-12
# Thread-11
#
# https://www.google.com
#
# Google
#
#
# Finished fetching : https://www.google.com
#
# Starting thread Thread-11
# Thread-9
#
# https://www.google.com
#
# Google
#
#
# Finished fetching : https://www.google.com
#
# Starting thread Thread-9
# Thread-13
#
# https://www.google.com
#
# Google
#
#
# Finished fetching : https://www.google.com
#
# Starting thread Thread-13
# Thread-12
#
# https://www.google.com
#
# Google
#
#
# Finished fetching : https://www.google.com
# Thread-10
#
# https://www.google.com
#
# Google
#
#
# Finished fetching : https://www.google.com
#
# Starting thread Thread-12
# Thread-11
#
# https://www.google.com
#
# Google
#
#
# Finished fetching : https://www.google.com
#
# Starting thread Thread-10
#
# Starting thread Thread-11
# Thread-12
#
# https://www.google.com
#
# Google
#
#
# Finished fetching : https://www.google.com
# Thread-13
#
# https://www.google.com
#
# Google
#
#
# Finished fetching : https://www.google.com
#
# Starting thread Thread-12
#
# Starting thread Thread-13
# Thread-10
#
# https://www.google.com
#
# Google
#
#
# Finished fetching : https://www.google.com
# Thread-9
#
# https://www.google.com
#
# Google
#
#
# Finished fetching : https://www.google.com
# Thread-11
#
# https://www.google.com
#
# Google
#
#
# Finished fetching : https://www.google.com
#
# Starting thread Thread-10
#
# Starting thread Thread-9
#
# Starting thread Thread-11
# Thread-12
#
# https://www.google.com
#
# Google
#
#
# Finished fetching : https://www.google.com
#
# Starting thread Thread-12
# Thread-13
#
# https://www.google.com
#
# Google
#
#
# Finished fetching : https://www.google.com
#
# Starting thread Thread-13
# Thread-10
#
# https://www.google.com
#
# Google
#
#
# Finished fetching : https://www.google.com
#
# Starting thread Thread-10
# Thread-11
#
# https://www.google.com
#
# Google
#
#
# Finished fetching : https://www.google.com
# Thread-9
#
# https://www.google.com
#
# Google
#
#
# Finished fetching : https://www.google.com
#
# Starting thread Thread-9
#
# Starting thread Thread-11
# Thread-12
#
# https://www.google.com
#
# Google
#
#
# Finished fetching : https://www.google.com
#
# Starting thread Thread-12
# Thread-10
#
# https://www.google.com
#
# Google
#
#
# Finished fetching : https://www.google.com
#
# Starting thread Thread-10
# Thread-13
#
# https://www.google.com
#
# Google
#
#
# Finished fetching : https://www.google.com
#
# Starting thread Thread-13
# Thread-9
#
# https://www.google.com
#
# Google
#
#
# Finished fetching : https://www.google.com
# Thread-11
#
# https://www.google.com
#
# Google
#
#
# Finished fetching : https://www.google.com
#
# Starting thread Thread-9
#
# Starting thread Thread-11
# Thread-12
#
# https://www.google.com
#
# Google
#
#
# Finished fetching : https://www.google.com
#
# Starting thread Thread-12
# Thread-10
#
# https://www.google.com
#
# Google
#
#
# Finished fetching : https://www.google.com
#
# Starting thread Thread-10
# Thread-11
#
# https://www.google.com
#
# Google
#
#
# Finished fetching : https://www.google.com
#
# Starting thread Thread-11
# Thread-9
#
# https://www.google.com
#
# Google
#
#
# Finished fetching : https://www.google.com
#
# Starting thread Thread-9
# Thread-13
#
# https://www.google.com
#
# Google
#
#
# Finished fetching : https://www.google.com
#
# Starting thread Thread-13
# Thread-12
#
# https://www.google.com
#
# Google
#
#
# Finished fetching : https://www.google.com
#
# Starting thread Thread-12
# Thread-10
#
# https://www.google.com
#
# Google
#
#
# Finished fetching : https://www.google.com
#
# Starting thread Thread-10
# Thread-11
#
# https://www.google.com
#
# Google
#
#
# Finished fetching : https://www.google.com
#
# Starting thread Thread-11
# Thread-13
#
# https://www.google.com
#
# Google
#
#
# Finished fetching : https://www.google.com
#
# Starting thread Thread-13
# Thread-9
#
# https://www.google.com
#
# Google
#
#
# Finished fetching : https://www.google.com
#
# Starting thread Thread-9
# Thread-12
#
# https://www.google.com
#
# Google
#
#
# Finished fetching : https://www.google.com
# Thread-10
#
# https://www.google.com
#
# Google
#
#
# Finished fetching : https://www.google.com
# Thread-11
#
# https://www.google.com
#
# Google
#
#
# Finished fetching : https://www.google.com
# Thread-13
#
# https://www.google.com
#
# Google
#
#
# Finished fetching : https://www.google.com
# Thread-9
#
# https://www.google.com
#
# Google
#
#
# Finished fetching : https://www.google.com
# [<_MainThread(MainThread, started 139814591846208)>, <Thread(Thread-2, started daemon 139814487684864)>, <Heartbeat(Thread-3, started daemon 139814405928704)>, <HistorySavingThread(IPythonHistorySavingThread, started 139814380750592)>, <ParentPollerUnix(Thread-1, started daemon 139814372357888)>, <Thread(ThreadPoolExecutor-0_0, started daemon 139814070384384)>, <Thread(ThreadPoolExecutor-0_1, started daemon 139814061991680)>, <Thread(ThreadPoolExecutor-0_2, started daemon 139814053598976)>, <Thread(ThreadPoolExecutor-0_3, started daemon 139814045206272)>, <Thread(ThreadPoolExecutor-0_4, started daemon 139814036813568)>, <Thread(ThreadPoolExecutor-0_5, started daemon 139814028420864)>, <Thread(ThreadPoolExecutor-0_6, started daemon 139814020028160)>, <Thread(ThreadPoolExecutor-0_7, started daemon 139813466404608)>, <Thread(ThreadPoolExecutor-0_8, started daemon 139813458011904)>, <Thread(ThreadPoolExecutor-0_9, started daemon 139813449619200)>, <Thread(ThreadPoolExecutor-0_10, started daemon 139813441226496)>, <Thread(ThreadPoolExecutor-0_11, started daemon 139813432833792)>, <Thread(ThreadPoolExecutor-0_12, started daemon 139813424441088)>, <Thread(ThreadPoolExecutor-0_13, started daemon 139813416048384)>, <Thread(ThreadPoolExecutor-0_14, started daemon 139812929533696)>, <Thread(ThreadPoolExecutor-0_15, started daemon 139812921140992)>, <Thread(Thread-4, started daemon 139812912748288)>, <Thread(Thread-5, started daemon 139812904355584)>, <Thread(Thread-6, started daemon 139812895962880)>, <Thread(Thread-7, started daemon 139812887570176)>, <Thread(Thread-8, started daemon 139812879177472)>, <Thread(Thread-9, started daemon 139812392662784)>, <Thread(Thread-10, started daemon 139812384270080)>, <Thread(Thread-11, started daemon 139812375877376)>, <Thread(Thread-12, started daemon 139812367484672)>, <Thread(Thread-13, started daemon 139812359091968)>]
# Execution time = 2.67946
